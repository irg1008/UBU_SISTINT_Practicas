# %% [markdown]
# # Travesía del puente
#
# El objetivo del juego es ayudar a una familia a cruzar el puente. El puente se cruza en completa oscuridad por lo que se necesita una lampara para cruzarlo. Debido a la fragilidad del puente, solo dos personas pueden cruzarlo al mismo tiempo (y, evidentemente, en el mismo sentido). Cada persona cruza a un ritmo diferente y cuando dos personas estén cruzando a la vez deben avanzar al ritmo de la más lenta.

# %% [markdown]
# ## Reglas
#
# - Se tiene una lámpara que dura 30 segundos. Hay que cruzar antes de que se apague.
# - Solo dos personas máximo pueden cruzar a la vez. Avanzando al ritmo de la más lenta.
#
# ## Miembros de la familia
# - Hijo pequeño: 1s
# - Hijo mayor: 3s
# - Madre: 6s
# - Padre 8s
# - Abuelo 12s

# %% [markdown]
# ## Visualización:
#
# Podemos ver cómo sería la implementación final del juego de la travesía del puente en el siguiente enlace:
#
# https://www.youtube.com/watch?v=OBb_85OVqfs

# %% [markdown]
# # Definiendo estructuras de datos
#
#
# - Representamos el tiempo restante con una variable tiempo.
# - Representamos dónde se encuentra el candil con una variable booleana (True: Zona en peligro, False: Zona salvados)
#
# - Podemos definir cada uno de los familiares como una lista con su nombre y su coste al cruzar.
#
# - Vamos a tener una lista *salvados* con los familiares que ya han cruzado y otra lista *en_\peligro* con los familiares que faltan por cruzar.

# %% [markdown]
# Estado sería una clase que contendría las dos listas (*salvados*, *en_\peligro*), el tiempo y la variable candil.
#
# - Habría una función \_\_str\_\_ que devolvería como string la representación del estado
#
# - Habría una función \_\_eq\_\_ que devolvería si dos estados son iguales. Dos estados son iguales si sus representaciones en modo string lo son.
#
# - Habría un metodo \_\_hash\_\_ para poder usar EstadoTravesiaBase en un set y saber si ya ha sido visitado
#
# ```Python
# def __hash__(self):
#     return hash(self.__str__())
# ```

# %% [markdown]
# # ¿Como se implementaría un estado?
#
# ```Python
# class EstadoTravesiaBase:
#
#     def __init__(self):
#
#         self.tiempo = 30
#         self.candil = True
#
#         hijop = ["Hijo pequeño", 1]
#         # completa
#
#         self.en_peligro = []
#         self.salvados = []
#
#
#     def __str__(self):
#         rep = ''
#         # completa
#         return rep
#
#     def __eq__(self, other):
#         return self.__str__() == other.__str__()
#
#     def __hash__(self):
#         return hash(self.__str__())
# ```

# %%
class EstadoTravesiaBase:
    
    def __init__(self):

        self.tiempo = 30
        self.candil = True

        hijop = ["Hijo pequeño", 1]
        hijom = ["Hijo mayor", 3]
        madre = ["Madre", 6]
        padre = ["Padre", 8]
        abuelo = ["Abuelo", 12]

        self.en_peligro = [hijop, hijom, madre, padre, abuelo]
        self.salvados = []
        
        
    def __str__(self):
        rep = 'Candil {} Peligro {} Salvados {} Tiempo {} \n'.format(
            self.candil,[familiar[0] for familiar in self.en_peligro],
            [familiar[0] for familiar in self.salvados],self.tiempo)
        return rep
    
    def __eq__(self, other):        
        return self.__str__() == other.__str__()
    
    def __hash__(self):
        return hash(self.__str__())

# %%
# ejemplo de creación de un estado inicial
e1 =  EstadoTravesiaBase()
print(e1)
print("Longitud del número de elementos en situación de peligro")
print(len(e1.en_peligro))
# Out:
# Candil True Peligro ['Hijo pequeño', 'Hijo mayor', 'Madre', 'Padre', 'Abuelo'] Salvados [] Tiempo 30
#
# Longitud del número de elementos en situación de peligro
# 5

# %% [markdown]
# ## ¿Cuales serían serían los estados finales?
#
# - Para que quede más compacto vamos a tener un EstadoTravesiaBase solo con la definición del estado y una clase EstadoTravesia que añade las demás funciones necesarias para manipular el estado.
#
# - Hacer un EstadoTravesia que herede de EstadoTravesiaBase
#
# - Vamos a tener una función *es\_final()* que devuelve True si el tiempo <= 0 o *en\_peligro* es la lista vacia.
#
#
# Intenta hacer la función **is_final** dentro de EstadoTravesia. No pases la diapositiva hasta haberlo intentado.

# %% [markdown]
# Añade esto a la clase EstadoTravesia
#
# ```Python
# def is_final(self):
#         return len(self.en_peligro)==0 or self.tiempo <= 0
#
# ```

# %% [markdown]
# ## ¿Cual sería la función que genera los siguientes estados?
#
#
# - Al ir de *en_\peligro* a *salvados*  se van a mover 2 familiares y al ir de *salvados* a *en_\peligro* se va a mover solo 1.
# - Cuando el candil es True va a mover elementos de la lista *en_\peligro* a la lista *salvados* y si vale False lo contrario.
# - Cada vez que se hace un movimiento se descuenta el coste del familiar más lento a la variable tiempo y se cambia el valor de candil
#
# - Vamos a tener un operador mueve, esta función recibe una lista de familiares (que tendrá tamaño 1 o 2 según sea el valor del candil.)

# %% [markdown]
# Se puede tener una función auxiliar *get_posibles_movimientos* que nos diga que familiares se pueden mover en cada momento.
# - Esta función siempre devuelve **una lista de listas**.
#     - Si el candil es True va a devolver una lista con todas las combinaciones de 2 familiares posibles de la lista en_peligro. Cada combinación de 2 familiares es una lista.
#     - Si es False, es el caso en el que un familiar vuelve con el candil, habrá tantas posibilidades como familiares haya en la lista *salvados*. Como la función *mueve* recibe una lista, esta función devolverá listas de listas, cada uno de los posibles movimientos. Serán listas de tamaño 1.
#
# En cada movimiento se van a mover 1-2 familiares. Así que *get_posibles_movimientos* va a devolver una lista con todas las combinaciones de 1 y 2 familiares posibles.

# %% [markdown]
# ### Pistas implementación
#
# Para implementarlo se puede usar itertools.combinations que devuelve las posibles combinaciones de un tamaño dado
#
# ```Python
# from itertools import combinations
#
# x = ['a','b','c','d']
#
# list(combinations(x,2)) #devuelve una lista con todas las combinaciones de tamaño 2
# #list(combinations(x,1)) # devolvería una lista con todas las combinaciones de tamaño 1
# ```
#
# Se pueden eliminar elementos de una lista con *remove* y añadirlos con *append*
#
# ``` Python
# l1 = [1,2,3,4]
# l1.remove(2)
# print(l1)
# l1.append(5)
# print(l1)
# ```
#
# Intenta implementar una función **mueve(self,mov)** y la función que devuelve todos los posibles movimientos antes de pasar la página y ver la implementación del profesor

# %%
from itertools import combinations

class EstadoTravesia(EstadoTravesiaBase):    
   
    def is_final(self):
        return len(self.en_peligro)==0 or self.tiempo <= 0    
    
    def get_posibles_movimientos(self):        
        if self.candil:
            return list(combinations(self.en_peligro,2))
        else:
            return list(combinations(self.salvados,1))
        
    def mueve(self,mov):
        coste_max = 0
        for familiar in mov:            
            if familiar[1] > coste_max:
                coste_max = familiar[1]            
            if self.candil:
                self.en_peligro.remove(familiar)
                self.salvados.append(familiar)
            else:
                self.salvados.remove(familiar)
                self.en_peligro.append(familiar)                
        self.tiempo -=coste_max
        self.candil = not self.candil

# %%
# Ejemplo de como se usaría get_posibles_movimientos
e1 =  EstadoTravesia()
posible_movs = e1.get_posibles_movimientos()
posible_movs
# Out:
# [(['Hijo pequeño', 1], ['Hijo mayor', 3]),
#  (['Hijo pequeño', 1], ['Madre', 6]),
#  (['Hijo pequeño', 1], ['Padre', 8]),
#  (['Hijo pequeño', 1], ['Abuelo', 12]),
#  (['Hijo mayor', 3], ['Madre', 6]),
#  (['Hijo mayor', 3], ['Padre', 8]),
#  (['Hijo mayor', 3], ['Abuelo', 12]),
#  (['Madre', 6], ['Padre', 8]),
#  (['Madre', 6], ['Abuelo', 12]),
#  (['Padre', 8], ['Abuelo', 12])]

# %%
# Ejemplo de como se usaría mueve para realizar un movimiento

e1.mueve(posible_movs[0])
print(e1)
# Out:
# Candil False Peligro ['Madre', 'Padre', 'Abuelo'] Salvados ['Hijo pequeño', 'Hijo mayor'] Tiempo 27

# %% [markdown]
# # Ultimas adaptaciones
#
# ### Llevar un registro de los movimientos efectuados
#
# - Para recuperar la solución vamos a crear un nuevo atributo de EstadoTravesia llamado **registro** de tipo str.
# - Va a almacenar una nueva linea por cada movimiento efectuado.
#     - Habría que modificar la función mueve para llevar a cabo este registro.

# %%
from itertools import combinations

class EstadoTravesia(EstadoTravesiaBase):
    
    def __init__(self):
        EstadoTravesiaBase.__init__(self)
        self.registro ='Candil {} Peligro {} Salvados {} Tiempo {} \n'.format(
            self.candil,[familiar[0] for familiar in self.en_peligro],"",self.tiempo)       
        
    def is_final(self):
        return len(self.en_peligro)==0 or self.tiempo <= 0
    
    def get_posibles_movimientos(self):        
        if self.candil:
            return list(combinations(self.en_peligro,2))
        else:
            return list(combinations(self.salvados,1))
        
    def mueve(self,mov):
        coste_max = 0
        for familiar in mov:            
            if familiar[1] > coste_max:
                coste_max = familiar[1]            
            if self.candil:
                self.en_peligro.remove(familiar)
                self.salvados.append(familiar)
            else:
                self.salvados.remove(familiar)
                self.en_peligro.append(familiar)                
        self.tiempo -=coste_max
        self.candil = not self.candil         
        self.registro+='Candil {} Tiempo {} Muevo {} \n'.format(
            self.candil,self.tiempo,[familiar[0] for familiar in mov])

# %%
e1 =  EstadoTravesia()
posible_movs = e1.get_posibles_movimientos()
e1.mueve(posible_movs[0])
posible_movs = e1.get_posibles_movimientos()
e1.mueve(posible_movs[0])

print(e1.registro)
# Out:
# Candil True Peligro ['Hijo pequeño', 'Hijo mayor', 'Madre', 'Padre', 'Abuelo'] Salvados  Tiempo 30
# Candil False Tiempo 27 Muevo ['Hijo pequeño', 'Hijo mayor']
# Candil True Tiempo 26 Muevo ['Hijo pequeño']

# %%
# En este caso, a diferencia del justamente de arriba, estamos mostrando por pantalla cada uno de los movimientos,
# tantas veces como "llamadas" a "e1.get_posibles_movimientos()"
e1 =  EstadoTravesia()
posible_movs = e1.get_posibles_movimientos()
e1.mueve(posible_movs[0])
posible_movs = e1.get_posibles_movimientos()
e1.mueve(posible_movs[0])
posible_movs = e1.get_posibles_movimientos()
e1.mueve(posible_movs[0])
posible_movs = e1.get_posibles_movimientos()
e1.mueve(posible_movs[0])
posible_movs = e1.get_posibles_movimientos()
e1.mueve(posible_movs[0])

print(e1.registro)
# Out:
# Candil True Peligro ['Hijo pequeño', 'Hijo mayor', 'Madre', 'Padre', 'Abuelo'] Salvados  Tiempo 30
# Candil False Tiempo 27 Muevo ['Hijo pequeño', 'Hijo mayor']
# Candil True Tiempo 26 Muevo ['Hijo pequeño']
# Candil False Tiempo 18 Muevo ['Madre', 'Padre']
# Candil True Tiempo 15 Muevo ['Hijo mayor']
# Candil False Tiempo 3 Muevo ['Abuelo', 'Hijo pequeño']

# %% [markdown]
# # Resolución del problema: Búsqueda en profundidad
#
#
# ```Python
# def dfs(estadoInicial):
#     visitados, pila = set(), [estadoInicial]
#     while pila: # mientras queden elementos en la pila, cojo el primero
#         actual = pila.pop()
#
#         if is_meta(actual): # evaluo si es meta
#             return actual
#
#         if actual not in visitados: # si no es meta y no había sido visitado anteriormente lo expando
#             visitados.add(actual)
#             suc = sucesores(actual,visitados)
#             pila.extend(suc)
#
# ```
# Más explicaciones en la siguiente diapositiva

# %% [markdown]
# Recordatorio extends
# ```Python
# l1 = [1,2,3,4]
# l1.extend([5,6,7])
# l1
#
# [1, 2, 3, 4, 5, 6, 7]
#
# ```
# - Haría falta una función *is_meta* que devuelve True cuando todos los familiares están a salvo y el tiempo es mayor o igual que 0.
#
# - Haría falta una función sucesores que devuelve una lista de estados sucesores:
#     - genera un estado nuevo por cada posible movimiento que se pueda hacer
#     - no devuelve estados que ya estuviesen visitados
#     - cada estado que devuelve se genera de una copia del estado original, para no cambiar los valores del estado original. Pista  copia = copy.deepcopy(estado)
#     - si es un estado final devuelve la lista vacia
#
#
# - Intenta implementar ambas funciones antes de pasar de diapositiva.

# %%
import copy


def is_meta(estado):
    if len(estado.en_peligro)==0 and estado.tiempo>=0:
        return True
    else:
        return False
    
    
def sucesores(estado,visitados):
    
    if estado.is_final():
        return []    
    sucesores = []
    posible_movs = estado.get_posibles_movimientos()
    
    for mov in posible_movs:
        estadoCopy = copy.deepcopy(estado)
        estadoCopy.mueve(mov)
        
        if not estadoCopy in visitados:
            sucesores.append(estadoCopy)
            
    return sucesores

# %%
def dfs(estadoInicial):
    visitados, pila = set(), [estadoInicial]
    while pila:
        actual = pila.pop()
        # print(actual)

        if is_meta(actual):
            return actual        

        if actual not in visitados:
            visitados.add(actual)
            suc = sucesores(actual,visitados)
            pila.extend(suc)

# %%
e1 =  EstadoTravesia()
meta = dfs(e1)
print(meta.registro)
# Out:
# Candil True Peligro ['Hijo pequeño', 'Hijo mayor', 'Madre', 'Padre', 'Abuelo'] Salvados [] Tiempo 30
#
# Candil False Peligro ['Hijo pequeño', 'Hijo mayor', 'Madre'] Salvados ['Padre', 'Abuelo'] Tiempo 18
#
# Candil True Peligro ['Hijo pequeño', 'Hijo mayor', 'Madre', 'Abuelo'] Salvados ['Padre'] Tiempo 6
#
# Candil False Peligro ['Hijo pequeño', 'Hijo mayor'] Salvados ['Padre', 'Madre', 'Abuelo'] Tiempo -6
#
# Candil False Peligro ['Hijo pequeño', 'Madre'] Salvados ['Padre', 'Hijo mayor', 'Abuelo'] Tiempo -6
#
# Candil False Peligro ['Hijo pequeño', 'Abuelo'] Salvados ['Padre', 'Hijo mayor', 'Madre'] Tiempo 0
#
# Candil False Peligro ['Hijo mayor', 'Madre'] Salvados ['Padre', 'Hijo pequeño', 'Abuelo'] Tiempo -6
#
# Candil False Peligro ['Hijo mayor', 'Abuelo'] Salvados ['Padre', 'Hijo pequeño', 'Madre'] Tiempo 0
#
# Candil False Peligro ['Madre', 'Abuelo'] Salvados ['Padre', 'Hijo pequeño', 'Hijo mayor'] Tiempo 3
#
# Candil True Peligro ['Madre', 'Abuelo', 'Hijo mayor'] Salvados ['Padre', 'Hijo pequeño'] Tiempo 0
#
# Candil True Peligro ['Madre', 'Abuelo', 'Hijo pequeño'] Salvados ['Padre', 'Hijo mayor'] Tiempo 2
#
# Candil False Peligro ['Madre'] Salvados ['Padre', 'Hijo mayor', 'Abuelo', 'Hijo pequeño'] Tiempo -10
#
# Candil False Peligro ['Abuelo'] Salvados ['Padre', 'Hijo mayor', 'Madre', 'Hijo pequeño'] Tiempo -4
#
# Candil False Peligro ['Hijo pequeño'] Salvados ['Padre', 'Hijo mayor', 'Madre', 'Abuelo'] Tiempo -10
#
# Candil True Peligro ['Madre', 'Abuelo', 'Padre'] Salvados ['Hijo pequeño', 'Hijo mayor'] Tiempo -5
#
# Candil True Peligro ['Hijo pequeño', 'Hijo mayor', 'Madre', 'Padre'] Salvados ['Abuelo'] Tiempo 10
#
# Candil False Peligro ['Hijo pequeño', 'Hijo mayor'] Salvados ['Abuelo', 'Madre', 'Padre'] Tiempo 2
#
# Candil True Peligro ['Hijo pequeño', 'Hijo mayor', 'Padre'] Salvados ['Abuelo', 'Madre'] Tiempo -6
#
# Candil True Peligro ['Hijo pequeño', 'Hijo mayor', 'Madre'] Salvados ['Abuelo', 'Padre'] Tiempo -4
#
# Candil True Peligro ['Hijo pequeño', 'Hijo mayor', 'Abuelo'] Salvados ['Madre', 'Padre'] Tiempo -10
#
# Candil False Peligro ['Hijo pequeño', 'Madre'] Salvados ['Abuelo', 'Hijo mayor', 'Padre'] Tiempo 2
#
# Candil True Peligro ['Hijo pequeño', 'Madre', 'Padre'] Salvados ['Abuelo', 'Hijo mayor'] Tiempo -6
#
# Candil True Peligro ['Hijo pequeño', 'Madre', 'Hijo mayor'] Salvados ['Abuelo', 'Padre'] Tiempo -1
#
# Candil True Peligro ['Hijo pequeño', 'Madre', 'Abuelo'] Salvados ['Hijo mayor', 'Padre'] Tiempo -10
#
# Candil False Peligro ['Hijo pequeño', 'Padre'] Salvados ['Abuelo', 'Hijo mayor', 'Madre'] Tiempo 4
#
# Candil True Peligro ['Hijo pequeño', 'Padre', 'Madre'] Salvados ['Abuelo', 'Hijo mayor'] Tiempo -2
#
# Candil True Peligro ['Hijo pequeño', 'Padre', 'Hijo mayor'] Salvados ['Abuelo', 'Madre'] Tiempo 1
#
# Candil False Peligro ['Hijo pequeño'] Salvados ['Abuelo', 'Madre', 'Padre', 'Hijo mayor'] Tiempo -7
#
# Candil False Peligro ['Padre'] Salvados ['Abuelo', 'Madre', 'Hijo pequeño', 'Hijo mayor'] Tiempo -2
#
# Candil False Peligro ['Hijo mayor'] Salvados ['Abuelo', 'Madre', 'Hijo pequeño', 'Padre'] Tiempo -7
#
# Candil True Peligro ['Hijo pequeño', 'Padre', 'Abuelo'] Salvados ['Hijo mayor', 'Madre'] Tiempo -8
#
# Candil False Peligro ['Hijo mayor', 'Madre'] Salvados ['Abuelo', 'Hijo pequeño', 'Padre'] Tiempo 2
#
# Candil True Peligro ['Hijo mayor', 'Madre', 'Padre'] Salvados ['Abuelo', 'Hijo pequeño'] Tiempo -6
#
# Candil True Peligro ['Hijo mayor', 'Madre', 'Hijo pequeño'] Salvados ['Abuelo', 'Padre'] Tiempo 1
#
# Candil False Peligro ['Hijo mayor'] Salvados ['Abuelo', 'Padre', 'Madre', 'Hijo pequeño'] Tiempo -5
#
# Candil False Peligro ['Madre'] Salvados ['Abuelo', 'Padre', 'Hijo mayor', 'Hijo pequeño'] Tiempo -2
#
# Candil False Peligro ['Hijo pequeño'] Salvados ['Abuelo', 'Padre', 'Hijo mayor', 'Madre'] Tiempo -5
#
# Candil True Peligro ['Hijo mayor', 'Madre', 'Abuelo'] Salvados ['Hijo pequeño', 'Padre'] Tiempo -10
#
# Candil False Peligro ['Hijo mayor', 'Padre'] Salvados ['Abuelo', 'Hijo pequeño', 'Madre'] Tiempo 4
#
# Candil True Peligro ['Hijo mayor', 'Padre', 'Madre'] Salvados ['Abuelo', 'Hijo pequeño'] Tiempo -2
#
# Candil True Peligro ['Hijo mayor', 'Padre', 'Hijo pequeño'] Salvados ['Abuelo', 'Madre'] Tiempo 3
#
# Candil False Peligro ['Hijo mayor'] Salvados ['Abuelo', 'Madre', 'Padre', 'Hijo pequeño'] Tiempo -5
#
# Candil False Peligro ['Padre'] Salvados ['Abuelo', 'Madre', 'Hijo mayor', 'Hijo pequeño'] Tiempo 0
#
# Candil False Peligro ['Hijo pequeño'] Salvados ['Abuelo', 'Madre', 'Hijo mayor', 'Padre'] Tiempo -5
#
# Candil True Peligro ['Hijo mayor', 'Padre', 'Abuelo'] Salvados ['Hijo pequeño', 'Madre'] Tiempo -8
#
# Candil False Peligro ['Madre', 'Padre'] Salvados ['Abuelo', 'Hijo pequeño', 'Hijo mayor'] Tiempo 7
#
# Candil True Peligro ['Madre', 'Padre', 'Hijo mayor'] Salvados ['Abuelo', 'Hijo pequeño'] Tiempo 4
#
# Candil False Peligro ['Madre'] Salvados ['Abuelo', 'Hijo pequeño', 'Padre', 'Hijo mayor'] Tiempo -4
#
# Candil False Peligro ['Padre'] Salvados ['Abuelo', 'Hijo pequeño', 'Madre', 'Hijo mayor'] Tiempo -2
#
# Candil False Peligro ['Hijo mayor'] Salvados ['Abuelo', 'Hijo pequeño', 'Madre', 'Padre'] Tiempo -4
#
# Candil True Peligro ['Madre', 'Padre', 'Hijo pequeño'] Salvados ['Abuelo', 'Hijo mayor'] Tiempo 6
#
# Candil False Peligro ['Madre'] Salvados ['Abuelo', 'Hijo mayor', 'Padre', 'Hijo pequeño'] Tiempo -2
#
# Candil False Peligro ['Padre'] Salvados ['Abuelo', 'Hijo mayor', 'Madre', 'Hijo pequeño'] Tiempo 0
#
# Candil False Peligro ['Hijo pequeño'] Salvados ['Abuelo', 'Hijo mayor', 'Madre', 'Padre'] Tiempo -2
#
# Candil True Peligro ['Madre', 'Padre', 'Abuelo'] Salvados ['Hijo pequeño', 'Hijo mayor'] Tiempo -5
#
# Candil False Peligro ['Hijo pequeño', 'Hijo mayor', 'Padre'] Salvados ['Madre', 'Abuelo'] Tiempo 18
#
# Candil True Peligro ['Hijo pequeño', 'Hijo mayor', 'Padre', 'Abuelo'] Salvados ['Madre'] Tiempo 6
#
# Candil False Peligro ['Hijo pequeño', 'Hijo mayor'] Salvados ['Madre', 'Padre', 'Abuelo'] Tiempo -6
#
# Candil False Peligro ['Hijo pequeño', 'Padre'] Salvados ['Madre', 'Hijo mayor', 'Abuelo'] Tiempo -6
#
# Candil False Peligro ['Hijo pequeño', 'Abuelo'] Salvados ['Madre', 'Hijo mayor', 'Padre'] Tiempo -2
#
# Candil False Peligro ['Hijo mayor', 'Padre'] Salvados ['Madre', 'Hijo pequeño', 'Abuelo'] Tiempo -6
#
# Candil False Peligro ['Hijo mayor', 'Abuelo'] Salvados ['Madre', 'Hijo pequeño', 'Padre'] Tiempo -2
#
# Candil False Peligro ['Padre', 'Abuelo'] Salvados ['Madre', 'Hijo pequeño', 'Hijo mayor'] Tiempo 3
#
# Candil True Peligro ['Padre', 'Abuelo', 'Hijo mayor'] Salvados ['Madre', 'Hijo pequeño'] Tiempo 0
#
# Candil True Peligro ['Padre', 'Abuelo', 'Hijo pequeño'] Salvados ['Madre', 'Hijo mayor'] Tiempo 2
#
# Candil False Peligro ['Padre'] Salvados ['Madre', 'Hijo mayor', 'Abuelo', 'Hijo pequeño'] Tiempo -10
#
# Candil False Peligro ['Abuelo'] Salvados ['Madre', 'Hijo mayor', 'Padre', 'Hijo pequeño'] Tiempo -6
#
# Candil False Peligro ['Hijo pequeño'] Salvados ['Madre', 'Hijo mayor', 'Padre', 'Abuelo'] Tiempo -10
#
# Candil True Peligro ['Padre', 'Abuelo', 'Madre'] Salvados ['Hijo pequeño', 'Hijo mayor'] Tiempo -3
#
# Candil True Peligro ['Hijo pequeño', 'Hijo mayor', 'Padre', 'Madre'] Salvados ['Abuelo'] Tiempo 12
#
# Candil False Peligro ['Hijo pequeño', 'Hijo mayor'] Salvados ['Abuelo', 'Padre', 'Madre'] Tiempo 4
#
# Candil True Peligro ['Hijo pequeño', 'Hijo mayor', 'Madre'] Salvados ['Abuelo', 'Padre'] Tiempo -2
#
# Candil True Peligro ['Hijo pequeño', 'Hijo mayor', 'Padre'] Salvados ['Abuelo', 'Madre'] Tiempo -4
#
# Candil True Peligro ['Hijo pequeño', 'Hijo mayor', 'Abuelo'] Salvados ['Padre', 'Madre'] Tiempo -8
#
# Candil False Peligro ['Hijo pequeño', 'Padre'] Salvados ['Abuelo', 'Hijo mayor', 'Madre'] Tiempo 6
#
# Candil True Peligro ['Hijo pequeño', 'Padre', 'Madre'] Salvados ['Abuelo', 'Hijo mayor'] Tiempo 0
#
# Candil True Peligro ['Hijo pequeño', 'Padre', 'Hijo mayor'] Salvados ['Abuelo', 'Madre'] Tiempo 3
#
# Candil False Peligro ['Hijo pequeño'] Salvados ['Abuelo', 'Madre', 'Padre', 'Hijo mayor'] Tiempo -5
#
# Candil False Peligro ['Padre'] Salvados ['Abuelo', 'Madre', 'Hijo pequeño', 'Hijo mayor'] Tiempo 0
#
# Candil False Peligro ['Hijo mayor'] Salvados ['Abuelo', 'Madre', 'Hijo pequeño', 'Padre'] Tiempo -5
#
# Candil True Peligro ['Hijo pequeño', 'Padre', 'Abuelo'] Salvados ['Hijo mayor', 'Madre'] Tiempo -6
#
# Candil False Peligro ['Hijo pequeño', 'Madre'] Salvados ['Abuelo', 'Hijo mayor', 'Padre'] Tiempo 4
#
# Candil True Peligro ['Hijo pequeño', 'Madre', 'Padre'] Salvados ['Abuelo', 'Hijo mayor'] Tiempo -4
#
# Candil True Peligro ['Hijo pequeño', 'Madre', 'Hijo mayor'] Salvados ['Abuelo', 'Padre'] Tiempo 1
#
# Candil False Peligro ['Hijo pequeño'] Salvados ['Abuelo', 'Padre', 'Madre', 'Hijo mayor'] Tiempo -5
#
# Candil False Peligro ['Madre'] Salvados ['Abuelo', 'Padre', 'Hijo pequeño', 'Hijo mayor'] Tiempo -2
#
# Candil False Peligro ['Hijo mayor'] Salvados ['Abuelo', 'Padre', 'Hijo pequeño', 'Madre'] Tiempo -5
#
# Candil True Peligro ['Hijo pequeño', 'Madre', 'Abuelo'] Salvados ['Hijo mayor', 'Padre'] Tiempo -8
#
# Candil False Peligro ['Hijo mayor', 'Padre'] Salvados ['Abuelo', 'Hijo pequeño', 'Madre'] Tiempo 6
#
# Candil True Peligro ['Hijo mayor', 'Padre', 'Madre'] Salvados ['Abuelo', 'Hijo pequeño'] Tiempo 0
#
# Candil True Peligro ['Hijo mayor', 'Padre', 'Hijo pequeño'] Salvados ['Abuelo', 'Madre'] Tiempo 5
#
# Candil False Peligro ['Hijo mayor'] Salvados ['Abuelo', 'Madre', 'Padre', 'Hijo pequeño'] Tiempo -3
#
# Candil False Peligro ['Padre'] Salvados ['Abuelo', 'Madre', 'Hijo mayor', 'Hijo pequeño'] Tiempo 2
#
# Candil True Peligro ['Padre', 'Hijo pequeño'] Salvados ['Abuelo', 'Madre', 'Hijo mayor'] Tiempo 1
#
# Candil False Peligro [] Salvados ['Abuelo', 'Madre', 'Hijo mayor', 'Padre', 'Hijo pequeño'] Tiempo -7
#
# Candil True Peligro ['Padre', 'Hijo mayor'] Salvados ['Abuelo', 'Madre', 'Hijo pequeño'] Tiempo -1
#
# Candil True Peligro ['Padre', 'Madre'] Salvados ['Abuelo', 'Hijo mayor', 'Hijo pequeño'] Tiempo -4
#
# Candil True Peligro ['Padre', 'Abuelo'] Salvados ['Madre', 'Hijo mayor', 'Hijo pequeño'] Tiempo -10
#
# Candil False Peligro ['Hijo pequeño'] Salvados ['Abuelo', 'Madre', 'Hijo mayor', 'Padre'] Tiempo -3
#
# Candil True Peligro ['Hijo mayor', 'Padre', 'Abuelo'] Salvados ['Hijo pequeño', 'Madre'] Tiempo -6
#
# Candil False Peligro ['Hijo mayor', 'Madre'] Salvados ['Abuelo', 'Hijo pequeño', 'Padre'] Tiempo 4
#
# Candil True Peligro ['Hijo mayor', 'Madre', 'Padre'] Salvados ['Abuelo', 'Hijo pequeño'] Tiempo -4
#
# Candil True Peligro ['Hijo mayor', 'Madre', 'Hijo pequeño'] Salvados ['Abuelo', 'Padre'] Tiempo 3
#
# Candil False Peligro ['Hijo mayor'] Salvados ['Abuelo', 'Padre', 'Madre', 'Hijo pequeño'] Tiempo -3
#
# Candil False Peligro ['Madre'] Salvados ['Abuelo', 'Padre', 'Hijo mayor', 'Hijo pequeño'] Tiempo 0
#
# Candil False Peligro ['Hijo pequeño'] Salvados ['Abuelo', 'Padre', 'Hijo mayor', 'Madre'] Tiempo -3
#
# Candil True Peligro ['Hijo mayor', 'Madre', 'Abuelo'] Salvados ['Hijo pequeño', 'Padre'] Tiempo -8
#
# Candil False Peligro ['Padre', 'Madre'] Salvados ['Abuelo', 'Hijo pequeño', 'Hijo mayor'] Tiempo 9
#
# Candil True Peligro ['Padre', 'Madre', 'Hijo mayor'] Salvados ['Abuelo', 'Hijo pequeño'] Tiempo 6
#
# Candil False Peligro ['Padre'] Salvados ['Abuelo', 'Hijo pequeño', 'Madre', 'Hijo mayor'] Tiempo 0
#
# Candil False Peligro ['Madre'] Salvados ['Abuelo', 'Hijo pequeño', 'Padre', 'Hijo mayor'] Tiempo -2
#
# Candil False Peligro ['Hijo mayor'] Salvados ['Abuelo', 'Hijo pequeño', 'Padre', 'Madre'] Tiempo -2
#
# Candil True Peligro ['Padre', 'Madre', 'Hijo pequeño'] Salvados ['Abuelo', 'Hijo mayor'] Tiempo 8
#
# Candil False Peligro ['Padre'] Salvados ['Abuelo', 'Hijo mayor', 'Madre', 'Hijo pequeño'] Tiempo 2
#
# Candil True Peligro ['Padre', 'Hijo pequeño'] Salvados ['Abuelo', 'Hijo mayor', 'Madre'] Tiempo 1
#
# Candil False Peligro [] Salvados ['Abuelo', 'Hijo mayor', 'Madre', 'Padre', 'Hijo pequeño'] Tiempo -7
#
# Candil True Peligro ['Padre', 'Abuelo'] Salvados ['Hijo mayor', 'Madre', 'Hijo pequeño'] Tiempo -10
#
# Candil False Peligro ['Madre'] Salvados ['Abuelo', 'Hijo mayor', 'Padre', 'Hijo pequeño'] Tiempo 0
#
# Candil False Peligro ['Hijo pequeño'] Salvados ['Abuelo', 'Hijo mayor', 'Padre', 'Madre'] Tiempo 0
#
# Candil True Peligro ['Padre', 'Madre', 'Abuelo'] Salvados ['Hijo pequeño', 'Hijo mayor'] Tiempo -3
#
# Candil False Peligro ['Hijo pequeño', 'Hijo mayor', 'Abuelo'] Salvados ['Madre', 'Padre'] Tiempo 22
#
# Candil True Peligro ['Hijo pequeño', 'Hijo mayor', 'Abuelo', 'Padre'] Salvados ['Madre'] Tiempo 14
#
# Candil False Peligro ['Hijo pequeño', 'Hijo mayor'] Salvados ['Madre', 'Abuelo', 'Padre'] Tiempo 2
#
# Candil True Peligro ['Hijo pequeño', 'Hijo mayor', 'Padre'] Salvados ['Madre', 'Abuelo'] Tiempo -6
#
# Candil False Peligro ['Hijo pequeño', 'Abuelo'] Salvados ['Madre', 'Hijo mayor', 'Padre'] Tiempo 6
#
# Candil True Peligro ['Hijo pequeño', 'Abuelo', 'Padre'] Salvados ['Madre', 'Hijo mayor'] Tiempo -2
#
# Candil True Peligro ['Hijo pequeño', 'Abuelo', 'Hijo mayor'] Salvados ['Madre', 'Padre'] Tiempo 3
#
# Candil False Peligro ['Hijo pequeño'] Salvados ['Madre', 'Padre', 'Abuelo', 'Hijo mayor'] Tiempo -9
#
# Candil False Peligro ['Abuelo'] Salvados ['Madre', 'Padre', 'Hijo pequeño', 'Hijo mayor'] Tiempo 0
#
# Candil False Peligro ['Hijo mayor'] Salvados ['Madre', 'Padre', 'Hijo pequeño', 'Abuelo'] Tiempo -9
#
# Candil True Peligro ['Hijo pequeño', 'Abuelo', 'Madre'] Salvados ['Hijo mayor', 'Padre'] Tiempo 0
#
# Candil False Peligro ['Hijo pequeño', 'Padre'] Salvados ['Madre', 'Hijo mayor', 'Abuelo'] Tiempo 2
#
# Candil True Peligro ['Hijo pequeño', 'Padre', 'Abuelo'] Salvados ['Madre', 'Hijo mayor'] Tiempo -10
#
# Candil True Peligro ['Hijo pequeño', 'Padre', 'Hijo mayor'] Salvados ['Madre', 'Abuelo'] Tiempo -1
#
# Candil True Peligro ['Hijo pequeño', 'Padre', 'Madre'] Salvados ['Hijo mayor', 'Abuelo'] Tiempo -4
#
# Candil False Peligro ['Hijo mayor', 'Abuelo'] Salvados ['Madre', 'Hijo pequeño', 'Padre'] Tiempo 6
#
# Candil True Peligro ['Hijo mayor', 'Abuelo', 'Padre'] Salvados ['Madre', 'Hijo pequeño'] Tiempo -2
#
# Candil True Peligro ['Hijo mayor', 'Abuelo', 'Hijo pequeño'] Salvados ['Madre', 'Padre'] Tiempo 5
#
# Candil False Peligro ['Hijo mayor'] Salvados ['Madre', 'Padre', 'Abuelo', 'Hijo pequeño'] Tiempo -7
#
# Candil False Peligro ['Abuelo'] Salvados ['Madre', 'Padre', 'Hijo mayor', 'Hijo pequeño'] Tiempo 2
#
# Candil True Peligro ['Abuelo', 'Hijo pequeño'] Salvados ['Madre', 'Padre', 'Hijo mayor'] Tiempo 1
#
# Candil False Peligro [] Salvados ['Madre', 'Padre', 'Hijo mayor', 'Abuelo', 'Hijo pequeño'] Tiempo -11
#
# Candil True Peligro ['Abuelo', 'Hijo mayor'] Salvados ['Madre', 'Padre', 'Hijo pequeño'] Tiempo -1
#
# Candil True Peligro ['Abuelo', 'Padre'] Salvados ['Madre', 'Hijo mayor', 'Hijo pequeño'] Tiempo -6
#
# Candil True Peligro ['Abuelo', 'Madre'] Salvados ['Padre', 'Hijo mayor', 'Hijo pequeño'] Tiempo -4
#
# Candil False Peligro ['Hijo pequeño'] Salvados ['Madre', 'Padre', 'Hijo mayor', 'Abuelo'] Tiempo -7
#
# Candil True Peligro ['Hijo mayor', 'Abuelo', 'Madre'] Salvados ['Hijo pequeño', 'Padre'] Tiempo 0
#
# Candil False Peligro ['Hijo mayor', 'Padre'] Salvados ['Madre', 'Hijo pequeño', 'Abuelo'] Tiempo 2
#
# Candil True Peligro ['Hijo mayor', 'Padre', 'Abuelo'] Salvados ['Madre', 'Hijo pequeño'] Tiempo -10
#
# Candil True Peligro ['Hijo mayor', 'Padre', 'Hijo pequeño'] Salvados ['Madre', 'Abuelo'] Tiempo 1
#
# Candil False Peligro ['Hijo mayor'] Salvados ['Madre', 'Abuelo', 'Padre', 'Hijo pequeño'] Tiempo -7
#
# Candil False Peligro ['Padre'] Salvados ['Madre', 'Abuelo', 'Hijo mayor', 'Hijo pequeño'] Tiempo -2
#
# Candil False Peligro ['Hijo pequeño'] Salvados ['Madre', 'Abuelo', 'Hijo mayor', 'Padre'] Tiempo -7
#
# Candil True Peligro ['Hijo mayor', 'Padre', 'Madre'] Salvados ['Hijo pequeño', 'Abuelo'] Tiempo -4
#
# Candil False Peligro ['Abuelo', 'Padre'] Salvados ['Madre', 'Hijo pequeño', 'Hijo mayor'] Tiempo 11
#
# Candil True Peligro ['Abuelo', 'Padre', 'Hijo mayor'] Salvados ['Madre', 'Hijo pequeño'] Tiempo 8
#
# Candil False Peligro ['Abuelo'] Salvados ['Madre', 'Hijo pequeño', 'Padre', 'Hijo mayor'] Tiempo 0
#
# Candil False Peligro ['Padre'] Salvados ['Madre', 'Hijo pequeño', 'Abuelo', 'Hijo mayor'] Tiempo -4
#
# Candil False Peligro ['Hijo mayor'] Salvados ['Madre', 'Hijo pequeño', 'Abuelo', 'Padre'] Tiempo -4
#
# Candil True Peligro ['Abuelo', 'Padre', 'Hijo pequeño'] Salvados ['Madre', 'Hijo mayor'] Tiempo 10
#
# Candil False Peligro ['Abuelo'] Salvados ['Madre', 'Hijo mayor', 'Padre', 'Hijo pequeño'] Tiempo 2
#
# Candil True Peligro ['Abuelo', 'Hijo pequeño'] Salvados ['Madre', 'Hijo mayor', 'Padre'] Tiempo 1
#
# Candil False Peligro [] Salvados ['Madre', 'Hijo mayor', 'Padre', 'Abuelo', 'Hijo pequeño'] Tiempo -11
#
# Candil True Peligro ['Abuelo', 'Madre'] Salvados ['Hijo mayor', 'Padre', 'Hijo pequeño'] Tiempo -4
#
# Candil False Peligro ['Padre'] Salvados ['Madre', 'Hijo mayor', 'Abuelo', 'Hijo pequeño'] Tiempo -2
#
# Candil False Peligro ['Hijo pequeño'] Salvados ['Madre', 'Hijo mayor', 'Abuelo', 'Padre'] Tiempo -2
#
# Candil True Peligro ['Abuelo', 'Padre', 'Madre'] Salvados ['Hijo pequeño', 'Hijo mayor'] Tiempo 5
#
# Candil False Peligro ['Abuelo'] Salvados ['Hijo pequeño', 'Hijo mayor', 'Padre', 'Madre'] Tiempo -3
#
# Candil False Peligro ['Padre'] Salvados ['Hijo pequeño', 'Hijo mayor', 'Abuelo', 'Madre'] Tiempo -7
#
# Candil False Peligro ['Madre'] Salvados ['Hijo pequeño', 'Hijo mayor', 'Abuelo', 'Padre'] Tiempo -7
#
# Candil True Peligro ['Hijo pequeño', 'Hijo mayor', 'Abuelo', 'Madre'] Salvados ['Padre'] Tiempo 16
#
# Candil False Peligro ['Hijo pequeño', 'Hijo mayor'] Salvados ['Padre', 'Abuelo', 'Madre'] Tiempo 4
#
# Candil True Peligro ['Hijo pequeño', 'Hijo mayor', 'Madre'] Salvados ['Padre', 'Abuelo'] Tiempo -2
#
# Candil False Peligro ['Hijo pequeño', 'Abuelo'] Salvados ['Padre', 'Hijo mayor', 'Madre'] Tiempo 10
#
# Candil True Peligro ['Hijo pequeño', 'Abuelo', 'Madre'] Salvados ['Padre', 'Hijo mayor'] Tiempo 4
#
# Candil False Peligro ['Hijo pequeño'] Salvados ['Padre', 'Hijo mayor', 'Abuelo', 'Madre'] Tiempo -8
#
# Candil False Peligro ['Abuelo'] Salvados ['Padre', 'Hijo mayor', 'Hijo pequeño', 'Madre'] Tiempo -2
#
# Candil False Peligro ['Madre'] Salvados ['Padre', 'Hijo mayor', 'Hijo pequeño', 'Abuelo'] Tiempo -8
#
# Candil True Peligro ['Hijo pequeño', 'Abuelo', 'Hijo mayor'] Salvados ['Padre', 'Madre'] Tiempo 7
#
# Candil False Peligro ['Hijo pequeño'] Salvados ['Padre', 'Madre', 'Abuelo', 'Hijo mayor'] Tiempo -5
#
# Candil False Peligro ['Abuelo'] Salvados ['Padre', 'Madre', 'Hijo pequeño', 'Hijo mayor'] Tiempo 4
#
# Candil True Peligro ['Abuelo', 'Hijo mayor'] Salvados ['Padre', 'Madre', 'Hijo pequeño'] Tiempo 1
#
# Candil False Peligro [] Salvados ['Padre', 'Madre', 'Hijo pequeño', 'Abuelo', 'Hijo mayor'] Tiempo -11
#
# Candil True Peligro ['Abuelo', 'Hijo pequeño'] Salvados ['Padre', 'Madre', 'Hijo mayor'] Tiempo 3
#
# Candil False Peligro [] Salvados ['Padre', 'Madre', 'Hijo mayor', 'Abuelo', 'Hijo pequeño'] Tiempo -9
#
# Candil True Peligro ['Abuelo', 'Madre'] Salvados ['Padre', 'Hijo pequeño', 'Hijo mayor'] Tiempo -2
#
# Candil True Peligro ['Abuelo', 'Padre'] Salvados ['Madre', 'Hijo pequeño', 'Hijo mayor'] Tiempo -4
#
# Candil False Peligro ['Hijo mayor'] Salvados ['Padre', 'Madre', 'Hijo pequeño', 'Abuelo'] Tiempo -5
#
# Candil True Peligro ['Hijo pequeño', 'Abuelo', 'Padre'] Salvados ['Hijo mayor', 'Madre'] Tiempo 2
#
# Candil False Peligro ['Hijo pequeño'] Salvados ['Hijo mayor', 'Madre', 'Abuelo', 'Padre'] Tiempo -10
#
# Candil False Peligro ['Abuelo'] Salvados ['Hijo mayor', 'Madre', 'Hijo pequeño', 'Padre'] Tiempo -6
#
# Candil False Peligro ['Padre'] Salvados ['Hijo mayor', 'Madre', 'Hijo pequeño', 'Abuelo'] Tiempo -10
#
# Candil False Peligro ['Hijo pequeño', 'Madre'] Salvados ['Padre', 'Hijo mayor', 'Abuelo'] Tiempo 4
#
# Candil True Peligro ['Hijo pequeño', 'Madre', 'Abuelo'] Salvados ['Padre', 'Hijo mayor'] Tiempo -8
#
# Candil True Peligro ['Hijo pequeño', 'Madre', 'Hijo mayor'] Salvados ['Padre', 'Abuelo'] Tiempo 1
#
# Candil False Peligro ['Hijo pequeño'] Salvados ['Padre', 'Abuelo', 'Madre', 'Hijo mayor'] Tiempo -5
#
# Candil False Peligro ['Madre'] Salvados ['Padre', 'Abuelo', 'Hijo pequeño', 'Hijo mayor'] Tiempo -2
#
# Candil False Peligro ['Hijo mayor'] Salvados ['Padre', 'Abuelo', 'Hijo pequeño', 'Madre'] Tiempo -5
#
# Candil True Peligro ['Hijo pequeño', 'Madre', 'Padre'] Salvados ['Hijo mayor', 'Abuelo'] Tiempo -4
#
# Candil False Peligro ['Hijo mayor', 'Abuelo'] Salvados ['Padre', 'Hijo pequeño', 'Madre'] Tiempo 10
#
# Candil True Peligro ['Hijo mayor', 'Abuelo', 'Madre'] Salvados ['Padre', 'Hijo pequeño'] Tiempo 4
#
# Candil False Peligro ['Hijo mayor'] Salvados ['Padre', 'Hijo pequeño', 'Abuelo', 'Madre'] Tiempo -8
#
# Candil False Peligro ['Abuelo'] Salvados ['Padre', 'Hijo pequeño', 'Hijo mayor', 'Madre'] Tiempo -2
#
# Candil False Peligro ['Madre'] Salvados ['Padre', 'Hijo pequeño', 'Hijo mayor', 'Abuelo'] Tiempo -8
#
# Candil True Peligro ['Hijo mayor', 'Abuelo', 'Hijo pequeño'] Salvados ['Padre', 'Madre'] Tiempo 9
#
# Candil False Peligro ['Hijo mayor'] Salvados ['Padre', 'Madre', 'Abuelo', 'Hijo pequeño'] Tiempo -3
#
# Candil False Peligro ['Abuelo'] Salvados ['Padre', 'Madre', 'Hijo mayor', 'Hijo pequeño'] Tiempo 6
#
# Candil True Peligro ['Abuelo', 'Hijo pequeño'] Salvados ['Padre', 'Madre', 'Hijo mayor'] Tiempo 5
#
# Candil False Peligro [] Salvados ['Padre', 'Madre', 'Hijo mayor', 'Abuelo', 'Hijo pequeño'] Tiempo -7
#
# Candil True Peligro ['Abuelo', 'Hijo mayor'] Salvados ['Padre', 'Madre', 'Hijo pequeño'] Tiempo 3
#
# Candil False Peligro [] Salvados ['Padre', 'Madre', 'Hijo pequeño', 'Abuelo', 'Hijo mayor'] Tiempo -9
#
# Candil True Peligro ['Abuelo', 'Madre'] Salvados ['Padre', 'Hijo mayor', 'Hijo pequeño'] Tiempo 0
#
# Candil True Peligro ['Abuelo', 'Padre'] Salvados ['Madre', 'Hijo mayor', 'Hijo pequeño'] Tiempo -2
#
# Candil False Peligro ['Hijo pequeño'] Salvados ['Padre', 'Madre', 'Hijo mayor', 'Abuelo'] Tiempo -3
#
# Candil True Peligro ['Hijo mayor', 'Abuelo', 'Padre'] Salvados ['Hijo pequeño', 'Madre'] Tiempo 2
#
# Candil False Peligro ['Hijo mayor'] Salvados ['Hijo pequeño', 'Madre', 'Abuelo', 'Padre'] Tiempo -10
#
# Candil False Peligro ['Abuelo'] Salvados ['Hijo pequeño', 'Madre', 'Hijo mayor', 'Padre'] Tiempo -6
#
# Candil False Peligro ['Padre'] Salvados ['Hijo pequeño', 'Madre', 'Hijo mayor', 'Abuelo'] Tiempo -10
#
# Candil False Peligro ['Hijo mayor', 'Madre'] Salvados ['Padre', 'Hijo pequeño', 'Abuelo'] Tiempo 4
#
# Candil True Peligro ['Hijo mayor', 'Madre', 'Abuelo'] Salvados ['Padre', 'Hijo pequeño'] Tiempo -8
#
# Candil True Peligro ['Hijo mayor', 'Madre', 'Hijo pequeño'] Salvados ['Padre', 'Abuelo'] Tiempo 3
#
# Candil False Peligro ['Hijo mayor'] Salvados ['Padre', 'Abuelo', 'Madre', 'Hijo pequeño'] Tiempo -3
#
# Candil False Peligro ['Madre'] Salvados ['Padre', 'Abuelo', 'Hijo mayor', 'Hijo pequeño'] Tiempo 0
#
# Candil False Peligro ['Hijo pequeño'] Salvados ['Padre', 'Abuelo', 'Hijo mayor', 'Madre'] Tiempo -3
#
# Candil True Peligro ['Hijo mayor', 'Madre', 'Padre'] Salvados ['Hijo pequeño', 'Abuelo'] Tiempo -4
#
# Candil False Peligro ['Abuelo', 'Madre'] Salvados ['Padre', 'Hijo pequeño', 'Hijo mayor'] Tiempo 13
#
# Candil True Peligro ['Abuelo', 'Madre', 'Hijo mayor'] Salvados ['Padre', 'Hijo pequeño'] Tiempo 10
#
# Candil False Peligro ['Abuelo'] Salvados ['Padre', 'Hijo pequeño', 'Madre', 'Hijo mayor'] Tiempo 4
#
# Candil True Peligro ['Abuelo', 'Hijo mayor'] Salvados ['Padre', 'Hijo pequeño', 'Madre'] Tiempo 1
#
# Candil False Peligro [] Salvados ['Padre', 'Hijo pequeño', 'Madre', 'Abuelo', 'Hijo mayor'] Tiempo -11
#
# Candil True Peligro ['Abuelo', 'Padre'] Salvados ['Hijo pequeño', 'Madre', 'Hijo mayor'] Tiempo -4
#
# Candil False Peligro ['Madre'] Salvados ['Padre', 'Hijo pequeño', 'Abuelo', 'Hijo mayor'] Tiempo -2
#
# Candil False Peligro ['Hijo mayor'] Salvados ['Padre', 'Hijo pequeño', 'Abuelo', 'Madre'] Tiempo -2
#
# Candil True Peligro ['Abuelo', 'Madre', 'Hijo pequeño'] Salvados ['Padre', 'Hijo mayor'] Tiempo 12
#
# Candil False Peligro ['Abuelo'] Salvados ['Padre', 'Hijo mayor', 'Madre', 'Hijo pequeño'] Tiempo 6
#
# Candil True Peligro ['Abuelo', 'Hijo pequeño'] Salvados ['Padre', 'Hijo mayor', 'Madre'] Tiempo 5
#
# Candil False Peligro [] Salvados ['Padre', 'Hijo mayor', 'Madre', 'Abuelo', 'Hijo pequeño'] Tiempo -7
#
# Candil True Peligro ['Abuelo', 'Padre'] Salvados ['Hijo mayor', 'Madre', 'Hijo pequeño'] Tiempo -2
#
# Candil False Peligro ['Madre'] Salvados ['Padre', 'Hijo mayor', 'Abuelo', 'Hijo pequeño'] Tiempo 0
#
# Candil False Peligro ['Hijo pequeño'] Salvados ['Padre', 'Hijo mayor', 'Abuelo', 'Madre'] Tiempo 0
#
# Candil True Peligro ['Abuelo', 'Madre', 'Padre'] Salvados ['Hijo pequeño', 'Hijo mayor'] Tiempo 5
#
# Candil False Peligro ['Abuelo'] Salvados ['Hijo pequeño', 'Hijo mayor', 'Madre', 'Padre'] Tiempo -3
#
# Candil False Peligro ['Hijo pequeño', 'Madre', 'Padre'] Salvados ['Hijo mayor', 'Abuelo'] Tiempo 18
#
# Candil True Peligro ['Hijo pequeño', 'Madre', 'Padre', 'Abuelo'] Salvados ['Hijo mayor'] Tiempo 6
#
# Candil False Peligro ['Hijo pequeño', 'Madre'] Salvados ['Hijo mayor', 'Padre', 'Abuelo'] Tiempo -6
#
# Candil False Peligro ['Hijo pequeño', 'Padre'] Salvados ['Hijo mayor', 'Madre', 'Abuelo'] Tiempo -6
#
# Candil False Peligro ['Hijo pequeño', 'Abuelo'] Salvados ['Hijo mayor', 'Madre', 'Padre'] Tiempo -2
#
# Candil False Peligro ['Madre', 'Padre'] Salvados ['Hijo mayor', 'Hijo pequeño', 'Abuelo'] Tiempo -6
#
# Candil False Peligro ['Madre', 'Abuelo'] Salvados ['Hijo mayor', 'Hijo pequeño', 'Padre'] Tiempo -2
#
# Candil False Peligro ['Padre', 'Abuelo'] Salvados ['Hijo mayor', 'Hijo pequeño', 'Madre'] Tiempo 0
#
# Candil True Peligro ['Hijo pequeño', 'Madre', 'Padre', 'Hijo mayor'] Salvados ['Abuelo'] Tiempo 15
#
# Candil False Peligro ['Hijo pequeño', 'Madre'] Salvados ['Abuelo', 'Padre', 'Hijo mayor'] Tiempo 7
#
# Candil True Peligro ['Hijo pequeño', 'Madre', 'Hijo mayor'] Salvados ['Abuelo', 'Padre'] Tiempo 4
#
# Candil False Peligro ['Hijo pequeño'] Salvados ['Abuelo', 'Padre', 'Madre', 'Hijo mayor'] Tiempo -2
#
# Candil False Peligro ['Madre'] Salvados ['Abuelo', 'Padre', 'Hijo pequeño', 'Hijo mayor'] Tiempo 1
#
# Candil True Peligro ['Madre', 'Hijo mayor'] Salvados ['Abuelo', 'Padre', 'Hijo pequeño'] Tiempo -2
#
# Candil True Peligro ['Madre', 'Hijo pequeño'] Salvados ['Abuelo', 'Padre', 'Hijo mayor'] Tiempo 0
#
# Candil True Peligro ['Madre', 'Padre'] Salvados ['Abuelo', 'Hijo pequeño', 'Hijo mayor'] Tiempo -7
#
# Candil True Peligro ['Madre', 'Abuelo'] Salvados ['Padre', 'Hijo pequeño', 'Hijo mayor'] Tiempo -11
#
# Candil False Peligro ['Hijo mayor'] Salvados ['Abuelo', 'Padre', 'Hijo pequeño', 'Madre'] Tiempo -2
#
# Candil True Peligro ['Hijo pequeño', 'Madre', 'Padre'] Salvados ['Abuelo', 'Hijo mayor'] Tiempo -1
#
# Candil True Peligro ['Hijo pequeño', 'Madre', 'Abuelo'] Salvados ['Padre', 'Hijo mayor'] Tiempo -5
#
# Candil False Peligro ['Hijo pequeño', 'Padre'] Salvados ['Abuelo', 'Madre', 'Hijo mayor'] Tiempo 9
#
# Candil True Peligro ['Hijo pequeño', 'Padre', 'Hijo mayor'] Salvados ['Abuelo', 'Madre'] Tiempo 6
#
# Candil False Peligro ['Hijo pequeño'] Salvados ['Abuelo', 'Madre', 'Padre', 'Hijo mayor'] Tiempo -2
#
# Candil False Peligro ['Padre'] Salvados ['Abuelo', 'Madre', 'Hijo pequeño', 'Hijo mayor'] Tiempo 3
#
# Candil True Peligro ['Padre', 'Hijo mayor'] Salvados ['Abuelo', 'Madre', 'Hijo pequeño'] Tiempo 0
#
# Candil True Peligro ['Padre', 'Hijo pequeño'] Salvados ['Abuelo', 'Madre', 'Hijo mayor'] Tiempo 2
#
# Candil False Peligro [] Salvados ['Abuelo', 'Madre', 'Hijo mayor', 'Padre', 'Hijo pequeño'] Tiempo -6
#
# Candil True Peligro ['Padre', 'Madre'] Salvados ['Abuelo', 'Hijo pequeño', 'Hijo mayor'] Tiempo -3
#
# Candil True Peligro ['Padre', 'Abuelo'] Salvados ['Madre', 'Hijo pequeño', 'Hijo mayor'] Tiempo -9
#
# Candil False Peligro ['Hijo mayor'] Salvados ['Abuelo', 'Madre', 'Hijo pequeño', 'Padre'] Tiempo -2
#
# Candil True Peligro ['Hijo pequeño', 'Padre', 'Madre'] Salvados ['Abuelo', 'Hijo mayor'] Tiempo 3
#
# Candil False Peligro ['Hijo pequeño'] Salvados ['Abuelo', 'Hijo mayor', 'Padre', 'Madre'] Tiempo -5
#
# Candil False Peligro ['Padre'] Salvados ['Abuelo', 'Hijo mayor', 'Hijo pequeño', 'Madre'] Tiempo -3
#
# Candil False Peligro ['Madre'] Salvados ['Abuelo', 'Hijo mayor', 'Hijo pequeño', 'Padre'] Tiempo -5
#
# Candil True Peligro ['Hijo pequeño', 'Padre', 'Abuelo'] Salvados ['Madre', 'Hijo mayor'] Tiempo -3
#
# Candil False Peligro ['Hijo pequeño', 'Hijo mayor'] Salvados ['Abuelo', 'Madre', 'Padre'] Tiempo 7
#
# Candil True Peligro ['Hijo pequeño', 'Hijo mayor', 'Padre'] Salvados ['Abuelo', 'Madre'] Tiempo -1
#
# Candil True Peligro ['Hijo pequeño', 'Hijo mayor', 'Madre'] Salvados ['Abuelo', 'Padre'] Tiempo 1
#
# Candil True Peligro ['Hijo pequeño', 'Hijo mayor', 'Abuelo'] Salvados ['Madre', 'Padre'] Tiempo -5
#
# Candil False Peligro ['Madre', 'Padre'] Salvados ['Abuelo', 'Hijo pequeño', 'Hijo mayor'] Tiempo 12
#
# Candil True Peligro ['Madre', 'Padre', 'Hijo mayor'] Salvados ['Abuelo', 'Hijo pequeño'] Tiempo 9
#
# Candil False Peligro ['Madre'] Salvados ['Abuelo', 'Hijo pequeño', 'Padre', 'Hijo mayor'] Tiempo 1
#
# Candil True Peligro ['Madre', 'Hijo mayor'] Salvados ['Abuelo', 'Hijo pequeño', 'Padre'] Tiempo -2
#
# Candil True Peligro ['Madre', 'Abuelo'] Salvados ['Hijo pequeño', 'Padre', 'Hijo mayor'] Tiempo -11
#
# Candil False Peligro ['Padre'] Salvados ['Abuelo', 'Hijo pequeño', 'Madre', 'Hijo mayor'] Tiempo 3
#
# Candil True Peligro ['Padre', 'Hijo mayor'] Salvados ['Abuelo', 'Hijo pequeño', 'Madre'] Tiempo 0
#
# Candil True Peligro ['Padre', 'Abuelo'] Salvados ['Hijo pequeño', 'Madre', 'Hijo mayor'] Tiempo -9
#
# Candil False Peligro ['Hijo mayor'] Salvados ['Abuelo', 'Hijo pequeño', 'Madre', 'Padre'] Tiempo 1
#
# Candil True Peligro ['Hijo mayor', 'Padre'] Salvados ['Abuelo', 'Hijo pequeño', 'Madre'] Tiempo -7
#
# Candil True Peligro ['Hijo mayor', 'Madre'] Salvados ['Abuelo', 'Hijo pequeño', 'Padre'] Tiempo -5
#
# Candil True Peligro ['Hijo mayor', 'Hijo pequeño'] Salvados ['Abuelo', 'Madre', 'Padre'] Tiempo 0
#
# Candil True Peligro ['Hijo mayor', 'Abuelo'] Salvados ['Hijo pequeño', 'Madre', 'Padre'] Tiempo -11
#
# Candil True Peligro ['Madre', 'Padre', 'Hijo pequeño'] Salvados ['Abuelo', 'Hijo mayor'] Tiempo 11
#
# Candil False Peligro ['Madre'] Salvados ['Abuelo', 'Hijo mayor', 'Padre', 'Hijo pequeño'] Tiempo 3
#
# Candil True Peligro ['Madre', 'Hijo pequeño'] Salvados ['Abuelo', 'Hijo mayor', 'Padre'] Tiempo 2
#
# Candil False Peligro [] Salvados ['Abuelo', 'Hijo mayor', 'Padre', 'Madre', 'Hijo pequeño'] Tiempo -4
#
# Candil True Peligro ['Madre', 'Padre'] Salvados ['Abuelo', 'Hijo mayor', 'Hijo pequeño'] Tiempo -5
#
# Candil True Peligro ['Madre', 'Hijo mayor'] Salvados ['Abuelo', 'Padre', 'Hijo pequeño'] Tiempo 0
#
# Candil True Peligro ['Madre', 'Abuelo'] Salvados ['Hijo mayor', 'Padre', 'Hijo pequeño'] Tiempo -9
#
# Candil False Peligro ['Padre'] Salvados ['Abuelo', 'Hijo mayor', 'Madre', 'Hijo pequeño'] Tiempo 5
#
# Candil True Peligro ['Padre', 'Hijo pequeño'] Salvados ['Abuelo', 'Hijo mayor', 'Madre'] Tiempo 4
#
# Candil False Peligro [] Salvados ['Abuelo', 'Hijo mayor', 'Madre', 'Padre', 'Hijo pequeño'] Tiempo -4
#
# Candil True Peligro ['Padre', 'Madre'] Salvados ['Abuelo', 'Hijo mayor', 'Hijo pequeño'] Tiempo -1
#
# Candil True Peligro ['Padre', 'Hijo mayor'] Salvados ['Abuelo', 'Madre', 'Hijo pequeño'] Tiempo 2
#
# Candil False Peligro [] Salvados ['Abuelo', 'Madre', 'Hijo pequeño', 'Padre', 'Hijo mayor'] Tiempo -6
#
# Candil True Peligro ['Padre', 'Abuelo'] Salvados ['Hijo mayor', 'Madre', 'Hijo pequeño'] Tiempo -7
#
# Candil False Peligro ['Hijo pequeño'] Salvados ['Abuelo', 'Hijo mayor', 'Madre', 'Padre'] Tiempo 3
#
# Candil True Peligro ['Hijo pequeño', 'Padre'] Salvados ['Abuelo', 'Hijo mayor', 'Madre'] Tiempo -5
#
# Candil True Peligro ['Hijo pequeño', 'Madre'] Salvados ['Abuelo', 'Hijo mayor', 'Padre'] Tiempo -3
#
# Candil True Peligro ['Hijo pequeño', 'Hijo mayor'] Salvados ['Abuelo', 'Madre', 'Padre'] Tiempo 0
#
# Candil True Peligro ['Hijo pequeño', 'Abuelo'] Salvados ['Hijo mayor', 'Madre', 'Padre'] Tiempo -9
#
# Candil True Peligro ['Madre', 'Padre', 'Abuelo'] Salvados ['Hijo pequeño', 'Hijo mayor'] Tiempo 0
#
# Candil False Peligro ['Madre', 'Hijo mayor'] Salvados ['Abuelo', 'Hijo pequeño', 'Padre'] Tiempo 7
#
# Candil True Peligro ['Madre', 'Hijo mayor', 'Padre'] Salvados ['Abuelo', 'Hijo pequeño'] Tiempo -1
#
# Candil True Peligro ['Madre', 'Hijo mayor', 'Hijo pequeño'] Salvados ['Abuelo', 'Padre'] Tiempo 6
#
# Candil False Peligro ['Madre'] Salvados ['Abuelo', 'Padre', 'Hijo mayor', 'Hijo pequeño'] Tiempo 3
#
# Candil True Peligro ['Madre', 'Hijo pequeño'] Salvados ['Abuelo', 'Padre', 'Hijo mayor'] Tiempo 2
#
# Candil False Peligro [] Salvados ['Abuelo', 'Padre', 'Hijo mayor', 'Madre', 'Hijo pequeño'] Tiempo -4
#
# Candil True Peligro ['Madre', 'Abuelo'] Salvados ['Padre', 'Hijo mayor', 'Hijo pequeño'] Tiempo -9
#
# Candil False Peligro ['Hijo mayor'] Salvados ['Abuelo', 'Padre', 'Madre', 'Hijo pequeño'] Tiempo 0
#
# Candil False Peligro ['Hijo pequeño'] Salvados ['Abuelo', 'Padre', 'Madre', 'Hijo mayor'] Tiempo 0
#
# Candil True Peligro ['Madre', 'Hijo mayor', 'Abuelo'] Salvados ['Hijo pequeño', 'Padre'] Tiempo -5
#
# Candil False Peligro ['Padre', 'Hijo mayor'] Salvados ['Abuelo', 'Hijo pequeño', 'Madre'] Tiempo 9
#
# Candil True Peligro ['Padre', 'Hijo mayor', 'Madre'] Salvados ['Abuelo', 'Hijo pequeño'] Tiempo 3
#
# Candil False Peligro ['Padre'] Salvados ['Abuelo', 'Hijo pequeño', 'Hijo mayor', 'Madre'] Tiempo -3
#
# Candil False Peligro ['Hijo mayor'] Salvados ['Abuelo', 'Hijo pequeño', 'Padre', 'Madre'] Tiempo -5
#
# Candil False Peligro ['Madre'] Salvados ['Abuelo', 'Hijo pequeño', 'Padre', 'Hijo mayor'] Tiempo -5
#
# Candil True Peligro ['Padre', 'Hijo mayor', 'Hijo pequeño'] Salvados ['Abuelo', 'Madre'] Tiempo 8
#
# Candil False Peligro ['Padre'] Salvados ['Abuelo', 'Madre', 'Hijo mayor', 'Hijo pequeño'] Tiempo 5
#
# Candil True Peligro ['Padre', 'Hijo pequeño'] Salvados ['Abuelo', 'Madre', 'Hijo mayor'] Tiempo 4
#
# Candil False Peligro [] Salvados ['Abuelo', 'Madre', 'Hijo mayor', 'Padre', 'Hijo pequeño'] Tiempo -4
#
# Candil True Peligro ['Padre', 'Abuelo'] Salvados ['Madre', 'Hijo mayor', 'Hijo pequeño'] Tiempo -7
#
# Candil False Peligro ['Hijo mayor'] Salvados ['Abuelo', 'Madre', 'Padre', 'Hijo pequeño'] Tiempo 0
#
# Candil False Peligro ['Hijo pequeño'] Salvados ['Abuelo', 'Madre', 'Padre', 'Hijo mayor'] Tiempo 0
#
# Candil True Peligro ['Padre', 'Hijo mayor', 'Abuelo'] Salvados ['Hijo pequeño', 'Madre'] Tiempo -3
#
# Candil False Peligro ['Hijo pequeño', 'Madre', 'Abuelo'] Salvados ['Hijo mayor', 'Padre'] Tiempo 22
#
# Candil True Peligro ['Hijo pequeño', 'Madre', 'Abuelo', 'Padre'] Salvados ['Hijo mayor'] Tiempo 14
#
# Candil False Peligro ['Hijo pequeño', 'Madre'] Salvados ['Hijo mayor', 'Abuelo', 'Padre'] Tiempo 2
#
# Candil True Peligro ['Hijo pequeño', 'Madre', 'Padre'] Salvados ['Hijo mayor', 'Abuelo'] Tiempo -6
#
# Candil False Peligro ['Hijo pequeño', 'Abuelo'] Salvados ['Hijo mayor', 'Madre', 'Padre'] Tiempo 6
#
# Candil True Peligro ['Hijo pequeño', 'Abuelo', 'Padre'] Salvados ['Hijo mayor', 'Madre'] Tiempo -2
#
# Candil False Peligro ['Hijo pequeño', 'Padre'] Salvados ['Hijo mayor', 'Madre', 'Abuelo'] Tiempo 2
#
# Candil True Peligro ['Hijo pequeño', 'Padre', 'Abuelo'] Salvados ['Hijo mayor', 'Madre'] Tiempo -10
#
# Candil False Peligro ['Madre', 'Abuelo'] Salvados ['Hijo mayor', 'Hijo pequeño', 'Padre'] Tiempo 6
#
# Candil True Peligro ['Madre', 'Abuelo', 'Padre'] Salvados ['Hijo mayor', 'Hijo pequeño'] Tiempo -2
#
# Candil True Peligro ['Madre', 'Abuelo', 'Hijo pequeño'] Salvados ['Hijo mayor', 'Padre'] Tiempo 5
#
# Candil False Peligro ['Madre'] Salvados ['Hijo mayor', 'Padre', 'Abuelo', 'Hijo pequeño'] Tiempo -7
#
# Candil False Peligro ['Abuelo'] Salvados ['Hijo mayor', 'Padre', 'Madre', 'Hijo pequeño'] Tiempo -1
#
# Candil False Peligro ['Hijo pequeño'] Salvados ['Hijo mayor', 'Padre', 'Madre', 'Abuelo'] Tiempo -7
#
# Candil True Peligro ['Madre', 'Abuelo', 'Hijo mayor'] Salvados ['Hijo pequeño', 'Padre'] Tiempo 3
#
# Candil False Peligro ['Madre'] Salvados ['Hijo pequeño', 'Padre', 'Abuelo', 'Hijo mayor'] Tiempo -9
#
# Candil False Peligro ['Abuelo'] Salvados ['Hijo pequeño', 'Padre', 'Madre', 'Hijo mayor'] Tiempo -3
#
# Candil False Peligro ['Hijo mayor'] Salvados ['Hijo pequeño', 'Padre', 'Madre', 'Abuelo'] Tiempo -9
#
# Candil False Peligro ['Madre', 'Padre'] Salvados ['Hijo mayor', 'Hijo pequeño', 'Abuelo'] Tiempo 2
#
# Candil True Peligro ['Madre', 'Padre', 'Abuelo'] Salvados ['Hijo mayor', 'Hijo pequeño'] Tiempo -10
#
# Candil True Peligro ['Madre', 'Padre', 'Hijo pequeño'] Salvados ['Hijo mayor', 'Abuelo'] Tiempo 1
#
# Candil False Peligro ['Madre'] Salvados ['Hijo mayor', 'Abuelo', 'Padre', 'Hijo pequeño'] Tiempo -7
#
# Candil False Peligro ['Padre'] Salvados ['Hijo mayor', 'Abuelo', 'Madre', 'Hijo pequeño'] Tiempo -5
#
# Candil False Peligro ['Hijo pequeño'] Salvados ['Hijo mayor', 'Abuelo', 'Madre', 'Padre'] Tiempo -7
#
# Candil True Peligro ['Madre', 'Padre', 'Hijo mayor'] Salvados ['Hijo pequeño', 'Abuelo'] Tiempo -1
#
# Candil False Peligro ['Abuelo', 'Padre'] Salvados ['Hijo mayor', 'Hijo pequeño', 'Madre'] Tiempo 8
#
# Candil True Peligro ['Abuelo', 'Padre', 'Madre'] Salvados ['Hijo mayor', 'Hijo pequeño'] Tiempo 2
#
# Candil False Peligro ['Abuelo'] Salvados ['Hijo mayor', 'Hijo pequeño', 'Padre', 'Madre'] Tiempo -6
#
# Candil False Peligro ['Padre'] Salvados ['Hijo mayor', 'Hijo pequeño', 'Abuelo', 'Madre'] Tiempo -10
#
# Candil False Peligro ['Madre'] Salvados ['Hijo mayor', 'Hijo pequeño', 'Abuelo', 'Padre'] Tiempo -10
#
# Candil True Peligro ['Abuelo', 'Padre', 'Hijo pequeño'] Salvados ['Hijo mayor', 'Madre'] Tiempo 7
#
# Candil False Peligro ['Abuelo'] Salvados ['Hijo mayor', 'Madre', 'Padre', 'Hijo pequeño'] Tiempo -1
#
# Candil False Peligro ['Padre'] Salvados ['Hijo mayor', 'Madre', 'Abuelo', 'Hijo pequeño'] Tiempo -5
#
# Candil False Peligro ['Hijo pequeño'] Salvados ['Hijo mayor', 'Madre', 'Abuelo', 'Padre'] Tiempo -5
#
# Candil True Peligro ['Abuelo', 'Padre', 'Hijo mayor'] Salvados ['Hijo pequeño', 'Madre'] Tiempo 5
#
# Candil False Peligro ['Abuelo'] Salvados ['Hijo pequeño', 'Madre', 'Padre', 'Hijo mayor'] Tiempo -3
#
# Candil False Peligro ['Padre'] Salvados ['Hijo pequeño', 'Madre', 'Abuelo', 'Hijo mayor'] Tiempo -7
#
# Candil False Peligro ['Hijo mayor'] Salvados ['Hijo pequeño', 'Madre', 'Abuelo', 'Padre'] Tiempo -7
#
# Candil True Peligro ['Hijo pequeño', 'Madre', 'Abuelo', 'Hijo mayor'] Salvados ['Padre'] Tiempo 19
#
# Candil False Peligro ['Hijo pequeño', 'Madre'] Salvados ['Padre', 'Abuelo', 'Hijo mayor'] Tiempo 7
#
# Candil True Peligro ['Hijo pequeño', 'Madre', 'Hijo mayor'] Salvados ['Padre', 'Abuelo'] Tiempo 4
#
# Candil False Peligro ['Hijo pequeño'] Salvados ['Padre', 'Abuelo', 'Madre', 'Hijo mayor'] Tiempo -2
#
# Candil False Peligro ['Madre'] Salvados ['Padre', 'Abuelo', 'Hijo pequeño', 'Hijo mayor'] Tiempo 1
#
# Candil True Peligro ['Madre', 'Hijo mayor'] Salvados ['Padre', 'Abuelo', 'Hijo pequeño'] Tiempo -2
#
# Candil True Peligro ['Madre', 'Hijo pequeño'] Salvados ['Padre', 'Abuelo', 'Hijo mayor'] Tiempo 0
#
# Candil False Peligro ['Hijo mayor'] Salvados ['Padre', 'Abuelo', 'Hijo pequeño', 'Madre'] Tiempo -2
#
# Candil False Peligro ['Hijo pequeño', 'Abuelo'] Salvados ['Padre', 'Madre', 'Hijo mayor'] Tiempo 13
#
# Candil True Peligro ['Hijo pequeño', 'Abuelo', 'Hijo mayor'] Salvados ['Padre', 'Madre'] Tiempo 10
#
# Candil False Peligro ['Hijo pequeño'] Salvados ['Padre', 'Madre', 'Abuelo', 'Hijo mayor'] Tiempo -2
#
# Candil False Peligro ['Abuelo'] Salvados ['Padre', 'Madre', 'Hijo pequeño', 'Hijo mayor'] Tiempo 7
#
# Candil True Peligro ['Abuelo', 'Hijo mayor'] Salvados ['Padre', 'Madre', 'Hijo pequeño'] Tiempo 4
#
# Candil False Peligro [] Salvados ['Padre', 'Madre', 'Hijo pequeño', 'Abuelo', 'Hijo mayor'] Tiempo -8
#
# Candil True Peligro ['Abuelo', 'Hijo pequeño'] Salvados ['Padre', 'Madre', 'Hijo mayor'] Tiempo 6
#
# Candil False Peligro [] Salvados ['Padre', 'Madre', 'Hijo mayor', 'Abuelo', 'Hijo pequeño'] Tiempo -6
#
# Candil True Peligro ['Abuelo', 'Madre'] Salvados ['Padre', 'Hijo pequeño', 'Hijo mayor'] Tiempo 1
#
# Candil False Peligro [] Salvados ['Padre', 'Hijo pequeño', 'Hijo mayor', 'Abuelo', 'Madre'] Tiempo -11
#
# Candil True Peligro ['Abuelo', 'Padre'] Salvados ['Madre', 'Hijo pequeño', 'Hijo mayor'] Tiempo -1
#
# Candil False Peligro ['Hijo mayor'] Salvados ['Padre', 'Madre', 'Hijo pequeño', 'Abuelo'] Tiempo -2
#
# Candil True Peligro ['Hijo pequeño', 'Abuelo', 'Madre'] Salvados ['Padre', 'Hijo mayor'] Tiempo 7
#
# Candil False Peligro ['Hijo pequeño'] Salvados ['Padre', 'Hijo mayor', 'Abuelo', 'Madre'] Tiempo -5
#
# Candil False Peligro ['Abuelo'] Salvados ['Padre', 'Hijo mayor', 'Hijo pequeño', 'Madre'] Tiempo 1
#
# Candil True Peligro ['Abuelo', 'Madre'] Salvados ['Padre', 'Hijo mayor', 'Hijo pequeño'] Tiempo -5
#
# Candil True Peligro ['Abuelo', 'Hijo pequeño'] Salvados ['Padre', 'Hijo mayor', 'Madre'] Tiempo 0
#
# Candil True Peligro ['Abuelo', 'Hijo mayor'] Salvados ['Padre', 'Hijo pequeño', 'Madre'] Tiempo -2
#
# Candil True Peligro ['Abuelo', 'Padre'] Salvados ['Hijo mayor', 'Hijo pequeño', 'Madre'] Tiempo -7
#
# Candil False Peligro ['Madre'] Salvados ['Padre', 'Hijo mayor', 'Hijo pequeño', 'Abuelo'] Tiempo -5
#
# Candil True Peligro ['Hijo pequeño', 'Abuelo', 'Padre'] Salvados ['Madre', 'Hijo mayor'] Tiempo 5
#
# Candil False Peligro ['Hijo pequeño'] Salvados ['Madre', 'Hijo mayor', 'Abuelo', 'Padre'] Tiempo -7
#
# Candil False Peligro ['Abuelo'] Salvados ['Madre', 'Hijo mayor', 'Hijo pequeño', 'Padre'] Tiempo -3
#
# Candil False Peligro ['Padre'] Salvados ['Madre', 'Hijo mayor', 'Hijo pequeño', 'Abuelo'] Tiempo -7
#
# Candil False Peligro ['Hijo pequeño', 'Hijo mayor'] Salvados ['Padre', 'Madre', 'Abuelo'] Tiempo 7
#
# Candil True Peligro ['Hijo pequeño', 'Hijo mayor', 'Abuelo'] Salvados ['Padre', 'Madre'] Tiempo -5
#
# Candil True Peligro ['Hijo pequeño', 'Hijo mayor', 'Madre'] Salvados ['Padre', 'Abuelo'] Tiempo 1
#
# Candil False Peligro ['Hijo pequeño'] Salvados ['Padre', 'Abuelo', 'Hijo mayor', 'Madre'] Tiempo -5
#
# Candil True Peligro ['Hijo pequeño', 'Hijo mayor', 'Padre'] Salvados ['Madre', 'Abuelo'] Tiempo -1
#
# Candil False Peligro ['Madre', 'Abuelo'] Salvados ['Padre', 'Hijo pequeño', 'Hijo mayor'] Tiempo 16
#
# Candil True Peligro ['Madre', 'Abuelo', 'Hijo mayor'] Salvados ['Padre', 'Hijo pequeño'] Tiempo 13
#
# Candil False Peligro ['Madre'] Salvados ['Padre', 'Hijo pequeño', 'Abuelo', 'Hijo mayor'] Tiempo 1
#
# Candil True Peligro ['Madre', 'Hijo mayor'] Salvados ['Padre', 'Hijo pequeño', 'Abuelo'] Tiempo -2
#
# Candil True Peligro ['Madre', 'Padre'] Salvados ['Hijo pequeño', 'Abuelo', 'Hijo mayor'] Tiempo -7
#
# Candil False Peligro ['Abuelo'] Salvados ['Padre', 'Hijo pequeño', 'Madre', 'Hijo mayor'] Tiempo 7
#
# Candil True Peligro ['Abuelo', 'Hijo mayor'] Salvados ['Padre', 'Hijo pequeño', 'Madre'] Tiempo 4
#
# Candil False Peligro [] Salvados ['Padre', 'Hijo pequeño', 'Madre', 'Abuelo', 'Hijo mayor'] Tiempo -8
#
# Candil True Peligro ['Abuelo', 'Padre'] Salvados ['Hijo pequeño', 'Madre', 'Hijo mayor'] Tiempo -1
#
# Candil False Peligro ['Hijo mayor'] Salvados ['Padre', 'Hijo pequeño', 'Madre', 'Abuelo'] Tiempo 1
#
# Candil True Peligro ['Hijo mayor', 'Abuelo'] Salvados ['Padre', 'Hijo pequeño', 'Madre'] Tiempo -11
#
# Candil True Peligro ['Hijo mayor', 'Madre'] Salvados ['Padre', 'Hijo pequeño', 'Abuelo'] Tiempo -5
#
# Candil True Peligro ['Hijo mayor', 'Hijo pequeño'] Salvados ['Padre', 'Madre', 'Abuelo'] Tiempo 0
#
# Candil True Peligro ['Hijo mayor', 'Padre'] Salvados ['Hijo pequeño', 'Madre', 'Abuelo'] Tiempo -7
#
# Candil True Peligro ['Madre', 'Abuelo', 'Hijo pequeño'] Salvados ['Padre', 'Hijo mayor'] Tiempo 15
#
# Candil False Peligro ['Madre'] Salvados ['Padre', 'Hijo mayor', 'Abuelo', 'Hijo pequeño'] Tiempo 3
#
# Candil True Peligro ['Madre', 'Hijo pequeño'] Salvados ['Padre', 'Hijo mayor', 'Abuelo'] Tiempo 2
#
# Candil False Peligro [] Salvados ['Padre', 'Hijo mayor', 'Abuelo', 'Madre', 'Hijo pequeño'] Tiempo -4
#
# Candil True Peligro ['Madre', 'Hijo mayor'] Salvados ['Padre', 'Abuelo', 'Hijo pequeño'] Tiempo 0
#
# Candil True Peligro ['Madre', 'Padre'] Salvados ['Hijo mayor', 'Abuelo', 'Hijo pequeño'] Tiempo -5
#
# Candil False Peligro ['Abuelo'] Salvados ['Padre', 'Hijo mayor', 'Madre', 'Hijo pequeño'] Tiempo 9
#
# Candil True Peligro ['Abuelo', 'Hijo pequeño'] Salvados ['Padre', 'Hijo mayor', 'Madre'] Tiempo 8
#
# Candil False Peligro [] Salvados ['Padre', 'Hijo mayor', 'Madre', 'Abuelo', 'Hijo pequeño'] Tiempo -4
#
# Candil True Peligro ['Abuelo', 'Madre'] Salvados ['Padre', 'Hijo mayor', 'Hijo pequeño'] Tiempo 3
#
# Candil False Peligro [] Salvados ['Padre', 'Hijo mayor', 'Hijo pequeño', 'Abuelo', 'Madre'] Tiempo -9
#
# Candil True Peligro ['Abuelo', 'Hijo mayor'] Salvados ['Padre', 'Madre', 'Hijo pequeño'] Tiempo 6
#
# Candil False Peligro [] Salvados ['Padre', 'Madre', 'Hijo pequeño', 'Abuelo', 'Hijo mayor'] Tiempo -6
#
# Candil True Peligro ['Abuelo', 'Padre'] Salvados ['Hijo mayor', 'Madre', 'Hijo pequeño'] Tiempo 1
#
# Candil False Peligro [] Salvados ['Hijo mayor', 'Madre', 'Hijo pequeño', 'Abuelo', 'Padre'] Tiempo -11
#
# Candil False Peligro ['Hijo pequeño'] Salvados ['Padre', 'Hijo mayor', 'Madre', 'Abuelo'] Tiempo 3
#
# Candil True Peligro ['Hijo pequeño', 'Abuelo'] Salvados ['Padre', 'Hijo mayor', 'Madre'] Tiempo -9
#
# Candil True Peligro ['Hijo pequeño', 'Madre'] Salvados ['Padre', 'Hijo mayor', 'Abuelo'] Tiempo -3
#
# Candil True Peligro ['Hijo pequeño', 'Hijo mayor'] Salvados ['Padre', 'Madre', 'Abuelo'] Tiempo 0
#
# Candil True Peligro ['Hijo pequeño', 'Padre'] Salvados ['Hijo mayor', 'Madre', 'Abuelo'] Tiempo -5
#
# Candil True Peligro ['Madre', 'Abuelo', 'Padre'] Salvados ['Hijo pequeño', 'Hijo mayor'] Tiempo 8
#
# Candil False Peligro ['Madre'] Salvados ['Hijo pequeño', 'Hijo mayor', 'Abuelo', 'Padre'] Tiempo -4
#
# Candil False Peligro ['Abuelo'] Salvados ['Hijo pequeño', 'Hijo mayor', 'Madre', 'Padre'] Tiempo 0
#
# Candil False Peligro ['Padre'] Salvados ['Hijo pequeño', 'Hijo mayor', 'Madre', 'Abuelo'] Tiempo -4
#
# Candil False Peligro ['Madre', 'Hijo mayor'] Salvados ['Padre', 'Hijo pequeño', 'Abuelo'] Tiempo 7
#
# Candil True Peligro ['Madre', 'Hijo mayor', 'Abuelo'] Salvados ['Padre', 'Hijo pequeño'] Tiempo -5
#
# Candil True Peligro ['Madre', 'Hijo mayor', 'Hijo pequeño'] Salvados ['Padre', 'Abuelo'] Tiempo 6
#
# Candil False Peligro ['Madre'] Salvados ['Padre', 'Abuelo', 'Hijo mayor', 'Hijo pequeño'] Tiempo 3
#
# Candil True Peligro ['Madre', 'Hijo pequeño'] Salvados ['Padre', 'Abuelo', 'Hijo mayor'] Tiempo 2
#
# Candil False Peligro [] Salvados ['Padre', 'Abuelo', 'Hijo mayor', 'Madre', 'Hijo pequeño'] Tiempo -4
#
# Candil False Peligro ['Hijo mayor'] Salvados ['Padre', 'Abuelo', 'Madre', 'Hijo pequeño'] Tiempo 0
#
# Candil False Peligro ['Hijo pequeño'] Salvados ['Padre', 'Abuelo', 'Madre', 'Hijo mayor'] Tiempo 0
#
# Candil True Peligro ['Madre', 'Hijo mayor', 'Padre'] Salvados ['Hijo pequeño', 'Abuelo'] Tiempo -1
#
# Candil False Peligro ['Abuelo', 'Hijo mayor'] Salvados ['Padre', 'Hijo pequeño', 'Madre'] Tiempo 13
#
# Candil True Peligro ['Abuelo', 'Hijo mayor', 'Madre'] Salvados ['Padre', 'Hijo pequeño'] Tiempo 7
#
# Candil False Peligro ['Abuelo'] Salvados ['Padre', 'Hijo pequeño', 'Hijo mayor', 'Madre'] Tiempo 1
#
# Candil True Peligro ['Abuelo', 'Madre'] Salvados ['Padre', 'Hijo pequeño', 'Hijo mayor'] Tiempo -5
#
# Candil True Peligro ['Abuelo', 'Padre'] Salvados ['Hijo pequeño', 'Hijo mayor', 'Madre'] Tiempo -7
#
# Candil False Peligro ['Hijo mayor'] Salvados ['Padre', 'Hijo pequeño', 'Abuelo', 'Madre'] Tiempo -5
#
# Candil False Peligro ['Madre'] Salvados ['Padre', 'Hijo pequeño', 'Abuelo', 'Hijo mayor'] Tiempo -5
#
# Candil True Peligro ['Abuelo', 'Hijo mayor', 'Hijo pequeño'] Salvados ['Padre', 'Madre'] Tiempo 12
#
# Candil False Peligro ['Abuelo'] Salvados ['Padre', 'Madre', 'Hijo mayor', 'Hijo pequeño'] Tiempo 9
#
# Candil True Peligro ['Abuelo', 'Hijo pequeño'] Salvados ['Padre', 'Madre', 'Hijo mayor'] Tiempo 8
#
# Candil False Peligro [] Salvados ['Padre', 'Madre', 'Hijo mayor', 'Abuelo', 'Hijo pequeño'] Tiempo -4
#
# Candil True Peligro ['Abuelo', 'Padre'] Salvados ['Madre', 'Hijo mayor', 'Hijo pequeño'] Tiempo 1
#
# Candil False Peligro [] Salvados ['Madre', 'Hijo mayor', 'Hijo pequeño', 'Abuelo', 'Padre'] Tiempo -11
#
# Candil False Peligro ['Hijo mayor'] Salvados ['Padre', 'Madre', 'Abuelo', 'Hijo pequeño'] Tiempo 0
#
# ...
#
# Candil True Peligro ['Hijo mayor', 'Abuelo', 'Padre'] Salvados ['Madre', 'Hijo pequeño'] Tiempo 7
#
# Candil False Peligro ['Hijo mayor'] Salvados ['Madre', 'Hijo pequeño', 'Abuelo', 'Padre'] Tiempo -5
#
# Candil False Peligro ['Abuelo'] Salvados ['Madre', 'Hijo pequeño', 'Hijo mayor', 'Padre'] Tiempo -1
#
# Candil False Peligro ['Padre'] Salvados ['Madre', 'Hijo pequeño', 'Hijo mayor', 'Abuelo'] Tiempo -5
#
# Candil False Peligro ['Hijo mayor', 'Hijo pequeño'] Salvados ['Padre', 'Madre', 'Abuelo'] Tiempo 9
#
# Candil True Peligro ['Hijo mayor', 'Hijo pequeño', 'Abuelo'] Salvados ['Padre', 'Madre'] Tiempo -3
#
# Candil True Peligro ['Hijo mayor', 'Hijo pequeño', 'Madre'] Salvados ['Padre', 'Abuelo'] Tiempo 3
#
# Candil True Peligro ['Hijo mayor', 'Hijo pequeño', 'Padre'] Salvados ['Madre', 'Abuelo'] Tiempo 1
#
# Candil False Peligro ['Madre', 'Abuelo'] Salvados ['Padre', 'Hijo mayor', 'Hijo pequeño'] Tiempo 18
#
# Candil True Peligro ['Madre', 'Abuelo', 'Hijo pequeño'] Salvados ['Padre', 'Hijo mayor'] Tiempo 17
#
# Candil False Peligro ['Madre'] Salvados ['Padre', 'Hijo mayor', 'Abuelo', 'Hijo pequeño'] Tiempo 5
#
# Candil True Peligro ['Madre', 'Hijo pequeño'] Salvados ['Padre', 'Hijo mayor', 'Abuelo'] Tiempo 4
#
# Candil False Peligro [] Salvados ['Padre', 'Hijo mayor', 'Abuelo', 'Madre', 'Hijo pequeño'] Tiempo -2
#
# Candil True Peligro ['Madre', 'Padre'] Salvados ['Hijo mayor', 'Abuelo', 'Hijo pequeño'] Tiempo -3
#
# Candil False Peligro ['Abuelo'] Salvados ['Padre', 'Hijo mayor', 'Madre', 'Hijo pequeño'] Tiempo 11
#
# Candil True Peligro ['Abuelo', 'Hijo pequeño'] Salvados ['Padre', 'Hijo mayor', 'Madre'] Tiempo 10
#
# Candil False Peligro [] Salvados ['Padre', 'Hijo mayor', 'Madre', 'Abuelo', 'Hijo pequeño'] Tiempo -2
#
# Candil True Peligro ['Abuelo', 'Padre'] Salvados ['Hijo mayor', 'Madre', 'Hijo pequeño'] Tiempo 3
#
# Candil False Peligro [] Salvados ['Hijo mayor', 'Madre', 'Hijo pequeño', 'Abuelo', 'Padre'] Tiempo -9
#
# Candil False Peligro ['Hijo pequeño'] Salvados ['Padre', 'Hijo mayor', 'Madre', 'Abuelo'] Tiempo 5
#
# Candil True Peligro ['Hijo pequeño', 'Abuelo'] Salvados ['Padre', 'Hijo mayor', 'Madre'] Tiempo -7
#
# Candil True Peligro ['Hijo pequeño', 'Madre'] Salvados ['Padre', 'Hijo mayor', 'Abuelo'] Tiempo -1
#
# Candil True Peligro ['Hijo pequeño', 'Hijo mayor'] Salvados ['Padre', 'Madre', 'Abuelo'] Tiempo 2
#
# Candil False Peligro [] Salvados ['Padre', 'Madre', 'Abuelo', 'Hijo pequeño', 'Hijo mayor'] Tiempo -1
#
# Candil True Peligro ['Hijo pequeño', 'Padre'] Salvados ['Hijo mayor', 'Madre', 'Abuelo'] Tiempo -3
#
# Candil True Peligro ['Madre', 'Abuelo', 'Hijo mayor'] Salvados ['Padre', 'Hijo pequeño'] Tiempo 15
#
# Candil False Peligro ['Madre'] Salvados ['Padre', 'Hijo pequeño', 'Abuelo', 'Hijo mayor'] Tiempo 3
#
# Candil True Peligro ['Madre', 'Hijo mayor'] Salvados ['Padre', 'Hijo pequeño', 'Abuelo'] Tiempo 0
#
# Candil True Peligro ['Madre', 'Padre'] Salvados ['Hijo pequeño', 'Abuelo', 'Hijo mayor'] Tiempo -5
#
# Candil False Peligro ['Abuelo'] Salvados ['Padre', 'Hijo pequeño', 'Madre', 'Hijo mayor'] Tiempo 9
#
# Candil True Peligro ['Abuelo', 'Hijo mayor'] Salvados ['Padre', 'Hijo pequeño', 'Madre'] Tiempo 6
#
# Candil False Peligro [] Salvados ['Padre', 'Hijo pequeño', 'Madre', 'Abuelo', 'Hijo mayor'] Tiempo -6
#
# Candil True Peligro ['Abuelo', 'Madre'] Salvados ['Padre', 'Hijo pequeño', 'Hijo mayor'] Tiempo 3
#
# Candil False Peligro [] Salvados ['Padre', 'Hijo pequeño', 'Hijo mayor', 'Abuelo', 'Madre'] Tiempo -9
#
# Candil True Peligro ['Abuelo', 'Padre'] Salvados ['Hijo pequeño', 'Madre', 'Hijo mayor'] Tiempo 1
#
# Candil False Peligro [] Salvados ['Hijo pequeño', 'Madre', 'Hijo mayor', 'Abuelo', 'Padre'] Tiempo -11
#
# Candil False Peligro ['Hijo mayor'] Salvados ['Padre', 'Hijo pequeño', 'Madre', 'Abuelo'] Tiempo 3
#
# Candil True Peligro ['Hijo mayor', 'Abuelo'] Salvados ['Padre', 'Hijo pequeño', 'Madre'] Tiempo -9
#
# Candil True Peligro ['Hijo mayor', 'Madre'] Salvados ['Padre', 'Hijo pequeño', 'Abuelo'] Tiempo -3
#
# Candil True Peligro ['Hijo mayor', 'Hijo pequeño'] Salvados ['Padre', 'Madre', 'Abuelo'] Tiempo 2
#
# Candil False Peligro [] Salvados ['Padre', 'Madre', 'Abuelo', 'Hijo mayor', 'Hijo pequeño'] Tiempo -1
#
# Candil True Peligro ['Hijo mayor', 'Padre'] Salvados ['Hijo pequeño', 'Madre', 'Abuelo'] Tiempo -5
#
# Candil True Peligro ['Madre', 'Abuelo', 'Padre'] Salvados ['Hijo mayor', 'Hijo pequeño'] Tiempo 10
#
# Candil False Peligro ['Madre'] Salvados ['Hijo mayor', 'Hijo pequeño', 'Abuelo', 'Padre'] Tiempo -2
#
# Candil False Peligro ['Abuelo'] Salvados ['Hijo mayor', 'Hijo pequeño', 'Madre', 'Padre'] Tiempo 2
#
# Candil True Peligro ['Abuelo', 'Padre'] Salvados ['Hijo mayor', 'Hijo pequeño', 'Madre'] Tiempo -6
#
# Candil True Peligro ['Abuelo', 'Madre'] Salvados ['Hijo mayor', 'Hijo pequeño', 'Padre'] Tiempo -4
#
# Candil True Peligro ['Abuelo', 'Hijo pequeño'] Salvados ['Hijo mayor', 'Madre', 'Padre'] Tiempo 1
#
# Candil False Peligro [] Salvados ['Hijo mayor', 'Madre', 'Padre', 'Abuelo', 'Hijo pequeño'] Tiempo -11
#
# Candil True Peligro ['Abuelo', 'Hijo mayor'] Salvados ['Hijo pequeño', 'Madre', 'Padre'] Tiempo -1
#
# Candil False Peligro ['Padre'] Salvados ['Hijo mayor', 'Hijo pequeño', 'Madre', 'Abuelo'] Tiempo -2
#
# Candil False Peligro ['Madre', 'Hijo pequeño'] Salvados ['Padre', 'Hijo mayor', 'Abuelo'] Tiempo 9
#
# Candil True Peligro ['Madre', 'Hijo pequeño', 'Abuelo'] Salvados ['Padre', 'Hijo mayor'] Tiempo -3
#
# Candil True Peligro ['Madre', 'Hijo pequeño', 'Hijo mayor'] Salvados ['Padre', 'Abuelo'] Tiempo 6
#
# Candil False Peligro ['Madre'] Salvados ['Padre', 'Abuelo', 'Hijo pequeño', 'Hijo mayor'] Tiempo 3
#
# Candil True Peligro ['Madre', 'Hijo pequeño', 'Padre'] Salvados ['Hijo mayor', 'Abuelo'] Tiempo 1
#
# Candil False Peligro ['Madre'] Salvados ['Hijo mayor', 'Abuelo', 'Hijo pequeño', 'Padre'] Tiempo -7
#
# Candil False Peligro ['Abuelo', 'Hijo pequeño'] Salvados ['Padre', 'Hijo mayor', 'Madre'] Tiempo 15
#
# Candil True Peligro ['Abuelo', 'Hijo pequeño', 'Madre'] Salvados ['Padre', 'Hijo mayor'] Tiempo 9
#
# Candil False Peligro ['Abuelo'] Salvados ['Padre', 'Hijo mayor', 'Hijo pequeño', 'Madre'] Tiempo 3
#
# Candil True Peligro ['Abuelo', 'Madre'] Salvados ['Padre', 'Hijo mayor', 'Hijo pequeño'] Tiempo -3
#
# Candil True Peligro ['Abuelo', 'Padre'] Salvados ['Hijo mayor', 'Hijo pequeño', 'Madre'] Tiempo -5
#
# Candil False Peligro ['Hijo pequeño'] Salvados ['Padre', 'Hijo mayor', 'Abuelo', 'Madre'] Tiempo -3
#
# Candil False Peligro ['Madre'] Salvados ['Padre', 'Hijo mayor', 'Abuelo', 'Hijo pequeño'] Tiempo -3
#
# Candil True Peligro ['Abuelo', 'Hijo pequeño', 'Hijo mayor'] Salvados ['Padre', 'Madre'] Tiempo 12
#
# Candil False Peligro ['Abuelo'] Salvados ['Padre', 'Madre', 'Hijo pequeño', 'Hijo mayor'] Tiempo 9
#
# Candil True Peligro ['Abuelo', 'Padre'] Salvados ['Madre', 'Hijo pequeño', 'Hijo mayor'] Tiempo 1
#
# Candil False Peligro [] Salvados ['Madre', 'Hijo pequeño', 'Hijo mayor', 'Abuelo', 'Padre'] Tiempo -11
#
# Candil True Peligro ['Abuelo', 'Hijo pequeño', 'Padre'] Salvados ['Hijo mayor', 'Madre'] Tiempo 7
#
# Candil False Peligro ['Abuelo'] Salvados ['Hijo mayor', 'Madre', 'Hijo pequeño', 'Padre'] Tiempo -1
#
# Candil False Peligro ['Hijo mayor', 'Padre', 'Abuelo'] Salvados ['Hijo pequeño', 'Madre'] Tiempo 24
#
# Candil True Peligro ['Hijo mayor', 'Padre', 'Abuelo', 'Madre'] Salvados ['Hijo pequeño'] Tiempo 18
#
# Candil False Peligro ['Hijo mayor', 'Padre'] Salvados ['Hijo pequeño', 'Abuelo', 'Madre'] Tiempo 6
#
# Candil True Peligro ['Hijo mayor', 'Padre', 'Madre'] Salvados ['Hijo pequeño', 'Abuelo'] Tiempo 0
#
# Candil False Peligro ['Hijo mayor', 'Abuelo'] Salvados ['Hijo pequeño', 'Padre', 'Madre'] Tiempo 10
#
# Candil True Peligro ['Hijo mayor', 'Abuelo', 'Madre'] Salvados ['Hijo pequeño', 'Padre'] Tiempo 4
#
# Candil False Peligro ['Hijo mayor'] Salvados ['Hijo pequeño', 'Padre', 'Abuelo', 'Madre'] Tiempo -8
#
# Candil False Peligro ['Abuelo'] Salvados ['Hijo pequeño', 'Padre', 'Hijo mayor', 'Madre'] Tiempo -2
#
# Candil False Peligro ['Madre'] Salvados ['Hijo pequeño', 'Padre', 'Hijo mayor', 'Abuelo'] Tiempo -8
#
# Candil False Peligro ['Hijo mayor', 'Madre'] Salvados ['Hijo pequeño', 'Padre', 'Abuelo'] Tiempo 6
#
# Candil True Peligro ['Hijo mayor', 'Madre', 'Abuelo'] Salvados ['Hijo pequeño', 'Padre'] Tiempo -6
#
# Candil True Peligro ['Hijo mayor', 'Madre', 'Padre'] Salvados ['Hijo pequeño', 'Abuelo'] Tiempo -2
#
# Candil True Peligro ['Hijo mayor', 'Madre', 'Hijo pequeño'] Salvados ['Padre', 'Abuelo'] Tiempo 5
#
# Candil False Peligro ['Hijo mayor'] Salvados ['Padre', 'Abuelo', 'Madre', 'Hijo pequeño'] Tiempo -1
#
# Candil False Peligro ['Madre'] Salvados ['Padre', 'Abuelo', 'Hijo mayor', 'Hijo pequeño'] Tiempo 2
#
# Candil True Peligro ['Madre', 'Hijo pequeño'] Salvados ['Padre', 'Abuelo', 'Hijo mayor'] Tiempo 1
#
# Candil False Peligro [] Salvados ['Padre', 'Abuelo', 'Hijo mayor', 'Madre', 'Hijo pequeño'] Tiempo -5
#
# Candil True Peligro ['Madre', 'Hijo mayor'] Salvados ['Padre', 'Abuelo', 'Hijo pequeño'] Tiempo -1
#
# Candil True Peligro ['Madre', 'Abuelo'] Salvados ['Padre', 'Hijo mayor', 'Hijo pequeño'] Tiempo -10
#
# Candil True Peligro ['Madre', 'Padre'] Salvados ['Abuelo', 'Hijo mayor', 'Hijo pequeño'] Tiempo -6
#
# Candil False Peligro ['Hijo pequeño'] Salvados ['Padre', 'Abuelo', 'Hijo mayor', 'Madre'] Tiempo -1
#
# Candil False Peligro ['Padre', 'Abuelo'] Salvados ['Hijo pequeño', 'Hijo mayor', 'Madre'] Tiempo 12
#
# Candil True Peligro ['Padre', 'Abuelo', 'Madre'] Salvados ['Hijo pequeño', 'Hijo mayor'] Tiempo 6
#
# Candil False Peligro ['Padre'] Salvados ['Hijo pequeño', 'Hijo mayor', 'Abuelo', 'Madre'] Tiempo -6
#
# Candil False Peligro ['Abuelo'] Salvados ['Hijo pequeño', 'Hijo mayor', 'Padre', 'Madre'] Tiempo -2
#
# Candil False Peligro ['Madre'] Salvados ['Hijo pequeño', 'Hijo mayor', 'Padre', 'Abuelo'] Tiempo -6
#
# Candil False Peligro ['Padre', 'Madre'] Salvados ['Hijo pequeño', 'Hijo mayor', 'Abuelo'] Tiempo 6
#
# Candil True Peligro ['Padre', 'Madre', 'Abuelo'] Salvados ['Hijo pequeño', 'Hijo mayor'] Tiempo -6
#
# Candil False Peligro ['Abuelo', 'Madre'] Salvados ['Hijo pequeño', 'Hijo mayor', 'Padre'] Tiempo 10
#
# Candil True Peligro ['Abuelo', 'Madre', 'Padre'] Salvados ['Hijo pequeño', 'Hijo mayor'] Tiempo 2
#
# Candil False Peligro ['Abuelo'] Salvados ['Hijo pequeño', 'Hijo mayor', 'Madre', 'Padre'] Tiempo -6
#
# Candil True Peligro ['Hijo mayor', 'Padre', 'Abuelo', 'Hijo pequeño'] Salvados ['Madre'] Tiempo 23
#
# Candil False Peligro ['Hijo mayor', 'Padre'] Salvados ['Madre', 'Abuelo', 'Hijo pequeño'] Tiempo 11
#
# Candil True Peligro ['Hijo mayor', 'Padre', 'Hijo pequeño'] Salvados ['Madre', 'Abuelo'] Tiempo 10
#
# Candil False Peligro ['Hijo mayor'] Salvados ['Madre', 'Abuelo', 'Padre', 'Hijo pequeño'] Tiempo 2
#
# Candil True Peligro ['Hijo mayor', 'Hijo pequeño'] Salvados ['Madre', 'Abuelo', 'Padre'] Tiempo 1
#
# Candil False Peligro [] Salvados ['Madre', 'Abuelo', 'Padre', 'Hijo mayor', 'Hijo pequeño'] Tiempo -2
#
# Candil False Peligro ['Padre'] Salvados ['Madre', 'Abuelo', 'Hijo mayor', 'Hijo pequeño'] Tiempo 7
#
# Candil True Peligro ['Padre', 'Hijo pequeño'] Salvados ['Madre', 'Abuelo', 'Hijo mayor'] Tiempo 6
#
# Candil False Peligro [] Salvados ['Madre', 'Abuelo', 'Hijo mayor', 'Padre', 'Hijo pequeño'] Tiempo -2
#
# Candil True Peligro ['Padre', 'Hijo mayor'] Salvados ['Madre', 'Abuelo', 'Hijo pequeño'] Tiempo 4
#
# Candil False Peligro [] Salvados ['Madre', 'Abuelo', 'Hijo pequeño', 'Padre', 'Hijo mayor'] Tiempo -4
#
# Candil False Peligro ['Hijo pequeño'] Salvados ['Madre', 'Abuelo', 'Hijo mayor', 'Padre'] Tiempo 2
#
# Candil True Peligro ['Hijo pequeño', 'Padre'] Salvados ['Madre', 'Abuelo', 'Hijo mayor'] Tiempo -6
#
# Candil True Peligro ['Hijo pequeño', 'Hijo mayor'] Salvados ['Madre', 'Abuelo', 'Padre'] Tiempo -1
#
# Candil False Peligro ['Hijo mayor', 'Abuelo'] Salvados ['Madre', 'Padre', 'Hijo pequeño'] Tiempo 15
#
# Candil True Peligro ['Hijo mayor', 'Abuelo', 'Hijo pequeño'] Salvados ['Madre', 'Padre'] Tiempo 14
#
# Candil False Peligro ['Hijo mayor'] Salvados ['Madre', 'Padre', 'Abuelo', 'Hijo pequeño'] Tiempo 2
#
# Candil True Peligro ['Hijo mayor', 'Hijo pequeño'] Salvados ['Madre', 'Padre', 'Abuelo'] Tiempo 1
#
# Candil False Peligro [] Salvados ['Madre', 'Padre', 'Abuelo', 'Hijo mayor', 'Hijo pequeño'] Tiempo -2
#
# Candil False Peligro ['Abuelo'] Salvados ['Madre', 'Padre', 'Hijo mayor', 'Hijo pequeño'] Tiempo 11
#
# Candil True Peligro ['Abuelo', 'Hijo pequeño'] Salvados ['Madre', 'Padre', 'Hijo mayor'] Tiempo 10
#
# Candil False Peligro [] Salvados ['Madre', 'Padre', 'Hijo mayor', 'Abuelo', 'Hijo pequeño'] Tiempo -2
#
# Candil True Peligro ['Abuelo', 'Hijo mayor'] Salvados ['Madre', 'Padre', 'Hijo pequeño'] Tiempo 8
#
# Candil False Peligro [] Salvados ['Madre', 'Padre', 'Hijo pequeño', 'Abuelo', 'Hijo mayor'] Tiempo -4
#
# Candil False Peligro ['Hijo pequeño'] Salvados ['Madre', 'Padre', 'Hijo mayor', 'Abuelo'] Tiempo 2
#
# Candil True Peligro ['Hijo pequeño', 'Abuelo'] Salvados ['Madre', 'Padre', 'Hijo mayor'] Tiempo -10
#
# Candil True Peligro ['Hijo pequeño', 'Hijo mayor'] Salvados ['Madre', 'Padre', 'Abuelo'] Tiempo -1
#
# Candil False Peligro ['Hijo mayor', 'Hijo pequeño'] Salvados ['Madre', 'Padre', 'Abuelo'] Tiempo 11
#
# Candil True Peligro ['Hijo mayor', 'Hijo pequeño', 'Abuelo'] Salvados ['Madre', 'Padre'] Tiempo -1
#
# Candil True Peligro ['Hijo mayor', 'Hijo pequeño', 'Padre'] Salvados ['Madre', 'Abuelo'] Tiempo 3
#
# Candil False Peligro ['Hijo mayor'] Salvados ['Madre', 'Abuelo', 'Hijo pequeño', 'Padre'] Tiempo -5
#
# Candil False Peligro ['Hijo pequeño'] Salvados ['Madre', 'Abuelo', 'Hijo mayor', 'Padre'] Tiempo -5
#
# Candil False Peligro ['Padre'] Salvados ['Madre', 'Abuelo', 'Hijo mayor', 'Hijo pequeño'] Tiempo 0
#
# Candil True Peligro ['Hijo mayor', 'Hijo pequeño', 'Madre'] Salvados ['Padre', 'Abuelo'] Tiempo 5
#
# Candil False Peligro ['Hijo mayor'] Salvados ['Padre', 'Abuelo', 'Hijo pequeño', 'Madre'] Tiempo -1
#
# Candil False Peligro ['Padre', 'Abuelo'] Salvados ['Madre', 'Hijo mayor', 'Hijo pequeño'] Tiempo 20
#
# Candil True Peligro ['Padre', 'Abuelo', 'Hijo pequeño'] Salvados ['Madre', 'Hijo mayor'] Tiempo 19
#
# Candil False Peligro ['Padre'] Salvados ['Madre', 'Hijo mayor', 'Abuelo', 'Hijo pequeño'] Tiempo 7
#
# Candil True Peligro ['Padre', 'Hijo pequeño'] Salvados ['Madre', 'Hijo mayor', 'Abuelo'] Tiempo 6
#
# Candil False Peligro [] Salvados ['Madre', 'Hijo mayor', 'Abuelo', 'Padre', 'Hijo pequeño'] Tiempo -2
#
# Candil True Peligro ['Padre', 'Madre'] Salvados ['Hijo mayor', 'Abuelo', 'Hijo pequeño'] Tiempo 1
#
# Candil False Peligro [] Salvados ['Hijo mayor', 'Abuelo', 'Hijo pequeño', 'Padre', 'Madre'] Tiempo -7
#
# Candil False Peligro ['Abuelo'] Salvados ['Madre', 'Hijo mayor', 'Padre', 'Hijo pequeño'] Tiempo 11
#
# Candil True Peligro ['Abuelo', 'Hijo pequeño'] Salvados ['Madre', 'Hijo mayor', 'Padre'] Tiempo 10
#
# Candil False Peligro [] Salvados ['Madre', 'Hijo mayor', 'Padre', 'Abuelo', 'Hijo pequeño'] Tiempo -2
#
# Candil True Peligro ['Abuelo', 'Madre'] Salvados ['Hijo mayor', 'Padre', 'Hijo pequeño'] Tiempo 5
#
# Candil False Peligro [] Salvados ['Hijo mayor', 'Padre', 'Hijo pequeño', 'Abuelo', 'Madre'] Tiempo -7
#
# Candil False Peligro ['Hijo pequeño'] Salvados ['Madre', 'Hijo mayor', 'Padre', 'Abuelo'] Tiempo 7
#
# Candil True Peligro ['Hijo pequeño', 'Abuelo'] Salvados ['Madre', 'Hijo mayor', 'Padre'] Tiempo -5
#
# Candil True Peligro ['Hijo pequeño', 'Padre'] Salvados ['Madre', 'Hijo mayor', 'Abuelo'] Tiempo -1
#
# Candil True Peligro ['Hijo pequeño', 'Hijo mayor'] Salvados ['Madre', 'Padre', 'Abuelo'] Tiempo 4
#
# Candil False Peligro [] Salvados ['Madre', 'Padre', 'Abuelo', 'Hijo pequeño', 'Hijo mayor'] Tiempo 1
#
# Candil True Peligro ['Hijo pequeño', 'Hijo mayor', 'Madre', 'Padre', 'Abuelo'] Salvados  Tiempo 30
# Candil False Tiempo 24 Muevo ['Hijo pequeño', 'Madre']
# Candil True Tiempo 23 Muevo ['Hijo pequeño']
# Candil False Tiempo 20 Muevo ['Hijo mayor', 'Hijo pequeño']
# Candil True Tiempo 19 Muevo ['Hijo pequeño']
# Candil False Tiempo 7 Muevo ['Padre', 'Abuelo']
# Candil True Tiempo 4 Muevo ['Hijo mayor']
# Candil False Tiempo 1 Muevo ['Hijo pequeño', 'Hijo mayor']
